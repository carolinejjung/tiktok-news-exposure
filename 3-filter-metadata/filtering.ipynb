# %%
import pandas as pd

hashtags = pd.read_csv('news_hashtags.csv')
creaters = pd.read_csv('news_creaters.csv')

# %%
hashtags
hashtags_list = hashtags['Hashtag name'].tolist()

# %%
#hashtags_list

# %%
creaters
creaters_list = creaters['Username'].tolist()

# %%
#creaters_list

# %%
dir_path = "/Users/sandyliu/tiktok-news-exposure/" # CHANGE ME!

# %%
file_to_process = dir_path + "2-collect-metadata-pyktok/final-metadata/results_69117.csv"
data_to_filter = pd.read_csv(file_to_process) #change this line to parse different files
data_to_filter
# Out:
#                   video_id      video_timestamp video_duration  \
# 0      7315561816673750318  2023-12-22T18:16:20           18.0
# 1      7331462048699649323  2024-02-03T14:37:35            8.0
# 2      7318253025649315104  2023-12-30T00:21:20            6.0
# 3      7331462048699649323  2024-02-03T14:37:35            8.0
# 4      7318253025649315104  2023-12-30T00:21:20            6.0
# ...                    ...                  ...            ...
# 15759  7318722296863149345  2023-12-31T06:40:36             16
# 15760  7335885936724692266  2024-02-15T12:45:09              9
# 15761  7338069156064988458  2024-02-21T09:57:03             36
# 15762  7331930122397797675  2024-02-04T20:53:59             48
# 15763  7304812867675491626  2023-11-23T19:04:52             98
#
#       video_locationcreated  \
# 0                        US
# 1                        US
# 2                        TH
# 3                        US
# 4                        TH
# ...                     ...
# 15759                    DE
# 15760                    US
# 15761                    US
# 15762                    US
# 15763                    US
#
#                                          suggested_words video_diggcount  \
# 0      flipnote, flipnote animation, asdf movie, flip...       3600000.0
# 1                                                    NaN          1111.0
# 2                                                    NaN          2208.0
# 3                                                    NaN          1111.0
# 4                                                    NaN          2208.0
# ...                                                  ...             ...
# 15759                                                NaN          522300
# 15760  Megatron Family Guy, parents aren't home you k...        12100000
# 15761  Car Air Freshener, Car Freshener, Car Freshene...           33300
# 15762  car accessories, car charger, retractable car ...         1200000
# 15763  Halara Leggings, halara, Halara Pants, Legging...          344400
#
#       video_sharecount video_commentcount video_playcount  \
# 0              40100.0            11000.0      19000000.0
# 1                  1.0                2.0          6589.0
# 2                  3.0                8.0         42400.0
# 3                  1.0                2.0          6589.0
# 4                  3.0                8.0         42400.0
# ...                ...                ...             ...
# 15759            23900               3032         9400000
# 15760           113100              26700        66400000
# 15761             3107                148         2100000
# 15762            37800               8297        35800000
# 15763             8355               2864        18000000
#
#                                        video_description video_is_ad  \
# 0                                 Bonus flipnote for you       False
# 1                                                    ☁️📙       False
# 2                             at 30 & 25 years of age 😂😂       False
# 3                                                    ☁️📙       False
# 4                             at 30 & 25 years of age 😂😂       False
# ...                                                  ...         ...
# 15759  Da muss SIE doch dran denken😱😂!!! #viral #fürd...       False
# 15760               Hes just a kitten but thats my dawg        False
# 15761  If you often smoke in the car, you really need...        True
# 15762  Replying to @DK BOSE this car charger soothes ...       False
# 15763  When i showed these to my husband he said and ...        True
#
#       video_stickers     author_username                 author_name  \
# 0                NaN     zanelittlemusic                 Zane Little
# 1                NaN          createbyua                          ua
# 2                NaN  confusedindiangirl            Savannah Sachdev
# 3                NaN          createbyua                          ua
# 4                NaN  confusedindiangirl            Savannah Sachdev
# ...              ...                 ...                         ...
# 15759            NaN         marie_tammo               𝐌𝐚𝐫𝐢𝐞 & 𝐓𝐚𝐦𝐦𝐨
# 15760            NaN       kyle.christie               Kyle Christie
# 15761            NaN              chidsj              Decsteamboy us
# 15762            NaN     insaneshopfinds  Insane TikTok Shop Deals 🎁
# 15763            NaN   alexisjohnson1019              Alexis Johnson
#
#       author_followercount author_followingcount author_heartcount  \
# 0                      NaN                   NaN               NaN
# 1                      NaN                   NaN               NaN
# 2                      NaN                   NaN               NaN
# 3                      NaN                   NaN               NaN
# 4                      NaN                   NaN               NaN
# ...                    ...                   ...               ...
# 15759                  NaN                   NaN               NaN
# 15760                  NaN                   NaN               NaN
# 15761                  NaN                   NaN               NaN
# 15762                  NaN                   NaN               NaN
# 15763                  NaN                   NaN               NaN
#
#       author_videocount author_diggcount author_verified
# 0                   NaN              NaN           False
# 1                   NaN              NaN           False
# 2                   NaN              NaN           False
# 3                   NaN              NaN           False
# 4                   NaN              NaN           False
# ...                 ...              ...             ...
# 15759               NaN              NaN           False
# 15760               NaN              NaN           False
# 15761               NaN              NaN           False
# 15762               NaN              NaN           False
# 15763               NaN              NaN           False
#
# [15764 rows x 20 columns]

# %%
data_to_filter = data_to_filter.loc[data_to_filter['video_locationcreated'] == 'US']

# %%
data_to_filter
# Out:
#                   video_id      video_timestamp video_duration  \
# 0      7315561816673750318  2023-12-22T18:16:20           18.0
# 1      7331462048699649323  2024-02-03T14:37:35            8.0
# 3      7331462048699649323  2024-02-03T14:37:35            8.0
# 5      7331462048699649323  2024-02-03T14:37:35            8.0
# 7      7322969142024342826  2024-01-11T17:20:34            5.0
# ...                    ...                  ...            ...
# 15758  7312626714775932190  2023-12-14T20:26:40              7
# 15760  7335885936724692266  2024-02-15T12:45:09              9
# 15761  7338069156064988458  2024-02-21T09:57:03             36
# 15762  7331930122397797675  2024-02-04T20:53:59             48
# 15763  7304812867675491626  2023-11-23T19:04:52             98
#
#       video_locationcreated  \
# 0                        US
# 1                        US
# 3                        US
# 5                        US
# 7                        US
# ...                     ...
# 15758                    US
# 15760                    US
# 15761                    US
# 15762                    US
# 15763                    US
#
#                                          suggested_words video_diggcount  \
# 0      flipnote, flipnote animation, asdf movie, flip...       3600000.0
# 1                                                    NaN          1111.0
# 3                                                    NaN          1111.0
# 5                                                    NaN          1111.0
# 7                                                    NaN           196.0
# ...                                                  ...             ...
# 15758                                                NaN          147500
# 15760  Megatron Family Guy, parents aren't home you k...        12100000
# 15761  Car Air Freshener, Car Freshener, Car Freshene...           33300
# 15762  car accessories, car charger, retractable car ...         1200000
# 15763  Halara Leggings, halara, Halara Pants, Legging...          344400
#
#       video_sharecount video_commentcount video_playcount  \
# 0              40100.0            11000.0      19000000.0
# 1                  1.0                2.0          6589.0
# 3                  1.0                2.0          6589.0
# 5                  1.0                2.0          6589.0
# 7                  0.0                7.0          5198.0
# ...                ...                ...             ...
# 15758              870               3916         1500000
# 15760           113100              26700        66400000
# 15761             3107                148         2100000
# 15762            37800               8297        35800000
# 15763             8355               2864        18000000
#
#                                        video_description video_is_ad  \
# 0                                 Bonus flipnote for you       False
# 1                                                    ☁️📙       False
# 3                                                    ☁️📙       False
# 5                                                    ☁️📙       False
# 7                   🥴😅👍🏾 #vegan #chipotle #veggie #food        False
# ...                                                  ...         ...
# 15758  guess the last 4 digits of my phone # ☎️ @Gavi...       False
# 15760               Hes just a kitten but thats my dawg        False
# 15761  If you often smoke in the car, you really need...        True
# 15762  Replying to @DK BOSE this car charger soothes ...       False
# 15763  When i showed these to my husband he said and ...        True
#
#       video_stickers    author_username                 author_name  \
# 0                NaN    zanelittlemusic                 Zane Little
# 1                NaN         createbyua                          ua
# 3                NaN         createbyua                          ua
# 5                NaN         createbyua                          ua
# 7                NaN    darlene_octavia              darleneoctavia
# ...              ...                ...                         ...
# 15758            NaN    lovealwayspiper                       Piper
# 15760            NaN      kyle.christie               Kyle Christie
# 15761            NaN             chidsj              Decsteamboy us
# 15762            NaN    insaneshopfinds  Insane TikTok Shop Deals 🎁
# 15763            NaN  alexisjohnson1019              Alexis Johnson
#
#       author_followercount author_followingcount author_heartcount  \
# 0                      NaN                   NaN               NaN
# 1                      NaN                   NaN               NaN
# 3                      NaN                   NaN               NaN
# 5                      NaN                   NaN               NaN
# 7                      NaN                   NaN               NaN
# ...                    ...                   ...               ...
# 15758                  NaN                   NaN               NaN
# 15760                  NaN                   NaN               NaN
# 15761                  NaN                   NaN               NaN
# 15762                  NaN                   NaN               NaN
# 15763                  NaN                   NaN               NaN
#
#       author_videocount author_diggcount author_verified
# 0                   NaN              NaN           False
# 1                   NaN              NaN           False
# 3                   NaN              NaN           False
# 5                   NaN              NaN           False
# 7                   NaN              NaN           False
# ...                 ...              ...             ...
# 15758               NaN              NaN           False
# 15760               NaN              NaN           False
# 15761               NaN              NaN           False
# 15762               NaN              NaN           False
# 15763               NaN              NaN           False
#
# [10284 rows x 20 columns]

# %%
data_to_filter = data_to_filter.loc[data_to_filter['video_is_ad'] == False]

# %%
data_to_filter
# Out:
# Empty DataFrame
# Columns: [video_id, video_timestamp, video_duration, video_locationcreated, suggested_words, video_diggcount, video_sharecount, video_commentcount, video_playcount, video_description, video_is_ad, video_stickers, author_username, author_name, author_followercount, author_followingcount, author_heartcount, author_videocount, author_diggcount, author_verified]
# Index: []

# %%
import re
def getHashtags(phrase):
    if isinstance(phrase, str):
        return re.findall(r'#(\S+)', phrase.lower())
    else:
        return []

data_to_filter['hashtags'] = data_to_filter['video_description'].apply(getHashtags)

def getSuggestedWords(phrase):
    if phrase is None:
        return []
    elif isinstance(phrase, str):
        return phrase.split(',')
    else:
        return []
    
data_to_filter['suggested_words'] = data_to_filter['suggested_words'].apply(getSuggestedWords)

# %%
data_to_filter
# Out:
# Empty DataFrame
# Columns: [video_id, video_timestamp, video_duration, video_locationcreated, suggested_words, video_diggcount, video_sharecount, video_commentcount, video_playcount, video_description, video_is_ad, video_stickers, author_username, author_name, author_followercount, author_followingcount, author_heartcount, author_videocount, author_diggcount, author_verified, hashtags]
# Index: []
#
# [0 rows x 21 columns]

# %%
def filter_conditions(row):
    has_hashtag = isinstance(row['hashtags'], list) and any(hashtag in row['hashtags'] for hashtag in hashtags_list)
    is_creator = row['author_username'] in creaters_list
    has_suggested_word = isinstance(row['suggested_words'], list) and any(word in row['suggested_words'] for word in hashtags_list)
    
    return has_hashtag or is_creator or has_suggested_word

data_to_filter_result = data_to_filter[data_to_filter.apply(filter_conditions, axis=1)]

## if hashtags is indeed a list, check if there is overlap between the video hashtag and the hashtag list or if the video 
## content creator is a news account. If any of the two is satisfied, pass to new dataset newsDF.

# %%
data_to_filter_result
## This result is actually a bit too weird
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
file_name = 'new_relevant_videos.csv' #change as needed
with open(file_name, 'w') as fout:
    data_to_filter_result.to_csv('new_relevant_videos_69117.csv')
