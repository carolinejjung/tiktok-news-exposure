# %%
import pandas as pd

hashtags = pd.read_csv('news_hashtags.csv')
creaters = pd.read_csv('news_creaters.csv')

# %%
hashtags
hashtags_list = hashtags['Hashtag name'].tolist()

# %%
#hashtags_list

# %%
creaters
creaters_list = creaters['Username'].tolist()

# %%
#creaters_list

# %%
dir_path = "/Users/sandyliu/tiktok-news-exposure/" # CHANGE ME!

# %%
file_to_process = dir_path + "2-collect-metadata-pyktok/final-metadata/results_26301.csv"
data_to_filter = pd.read_csv(file_to_process) #change this line to parse different files
data_to_filter
# Out:
#                  video_id      video_timestamp  video_duration  \
# 0     7315561816673750318  2023-12-22T18:16:20            18.0
# 1     7315561816673750318  2023-12-22T18:16:20            18.0
# 2     7315561816673750318  2023-12-22T18:16:20            18.0
# 3     7315561816673750318  2023-12-22T18:16:20            18.0
# 4     7315561816673750318  2023-12-22T18:16:20            18.0
# ...                   ...                  ...             ...
# 8063  7321132514330905899  2024-01-06T18:33:34            58.0
# 8064  7331962685812215042  2024-02-04T22:59:56             6.0
# 8065  7335549375667653934  2024-02-14T14:58:41            64.0
# 8066  7337225129354661153  2024-02-19T03:21:02            62.0
# 8067  7328816594363338030  2024-01-27T11:31:50            45.0
#
#      video_locationcreated                                    suggested_words  \
# 0                       US  flipnote, flipnote animation, asdf movie, flip...
# 1                       US  flipnote, flipnote animation, asdf movie, flip...
# 2                       US  flipnote, flipnote animation, asdf movie, flip...
# 3                       US  flipnote, flipnote animation, asdf movie, flip...
# 4                       US  flipnote, flipnote animation, asdf movie, flip...
# ...                    ...                                                ...
# 8063                    US  fake awake by tarte, Tarte Cosmetics, tubing m...
# 8064               FAKE-AD  Body Deodorant, Deodorant For Body Odor, Deodo...
# 8065                    US  Bk Beauty Brushes, bk beauty, concealer brush,...
# 8066                    GB                                                NaN
# 8067                    US  Hozier, hozier sweatshirt, hozierofficial, Hoz...
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0           3500000.0           39500.0             10800.0       18700000.0
# 1           3500000.0           39500.0             10800.0       18700000.0
# 2           3500000.0           39500.0             10800.0       18700000.0
# 3           3500000.0           39500.0             10800.0       18700000.0
# 4           3500000.0           39500.0             10800.0       18700000.0
# ...               ...               ...                 ...              ...
# 8063         107500.0            1162.0               521.0       18500000.0
# 8064           5589.0             118.0                92.0       10600000.0
# 8065          23200.0             113.0               205.0        1300000.0
# 8066          12600.0              84.0               439.0        3200000.0
# 8067         139400.0            3474.0               553.0        2700000.0
#
#                                       video_description  video_is_ad  \
# 0                                Bonus flipnote for you        False
# 1                                Bonus flipnote for you        False
# 2                                Bonus flipnote for you        False
# 3                                Bonus flipnote for you        False
# 4                                Bonus flipnote for you        False
# ...                                                 ...          ...
# 8063  Replying to @Ashley Hunsucker The Tarte trio d...         True
# 8064  72 HR odor protection from pits to bits. Avail...         True
# 8065  I’m a deal fiend, so I figured I would share. ...         True
# 8066  One Line 9 is actually so hard #oneline #filte...        False
# 8067  These lyrics are sunlight  #ilovehozier #hozie...        False
#
#       video_stickers       author_username      author_name  \
# 0                NaN       zanelittlemusic      Zane Little
# 1                NaN       zanelittlemusic      Zane Little
# 2                NaN       zanelittlemusic      Zane Little
# 3                NaN       zanelittlemusic      Zane Little
# 4                NaN       zanelittlemusic      Zane Little
# ...              ...                   ...              ...
# 8063             NaN          michellesays         Michelle
# 8064             NaN                Secret           Secret
# 8065             NaN   itsmakeupbymelissam  Melissa Murdick
# 8066             NaN              ethancaf         EthanC24
# 8067             NaN  melodyprints_theboys      HEVALLETTRE
#
#       author_followercount  author_followingcount  author_heartcount  \
# 0                      NaN                    NaN                NaN
# 1                      NaN                    NaN                NaN
# 2                      NaN                    NaN                NaN
# 3                      NaN                    NaN                NaN
# 4                      NaN                    NaN                NaN
# ...                    ...                    ...                ...
# 8063                   NaN                    NaN                NaN
# 8064                   NaN                    NaN                NaN
# 8065                   NaN                    NaN                NaN
# 8066                   NaN                    NaN                NaN
# 8067                   NaN                    NaN                NaN
#
#       author_videocount  author_diggcount  author_verified
# 0                   NaN               NaN            False
# 1                   NaN               NaN            False
# 2                   NaN               NaN            False
# 3                   NaN               NaN            False
# 4                   NaN               NaN            False
# ...                 ...               ...              ...
# 8063                NaN               NaN            False
# 8064                NaN               NaN            False
# 8065                NaN               NaN             True
# 8066                NaN               NaN            False
# 8067                NaN               NaN            False
#
# [8068 rows x 20 columns]

# %%
data_to_filter = data_to_filter.loc[data_to_filter['video_locationcreated'] == 'US']

# %%
data_to_filter
# Out:
#                  video_id      video_timestamp  video_duration  \
# 0     7315561816673750318  2023-12-22T18:16:20            18.0
# 1     7315561816673750318  2023-12-22T18:16:20            18.0
# 2     7315561816673750318  2023-12-22T18:16:20            18.0
# 3     7315561816673750318  2023-12-22T18:16:20            18.0
# 4     7315561816673750318  2023-12-22T18:16:20            18.0
# ...                   ...                  ...             ...
# 8061  7336803062230601002  2024-02-18T00:03:29             8.0
# 8062  7337420660160875819  2024-02-19T15:59:58            34.0
# 8063  7321132514330905899  2024-01-06T18:33:34            58.0
# 8065  7335549375667653934  2024-02-14T14:58:41            64.0
# 8067  7328816594363338030  2024-01-27T11:31:50            45.0
#
#      video_locationcreated                                    suggested_words  \
# 0                       US  flipnote, flipnote animation, asdf movie, flip...
# 1                       US  flipnote, flipnote animation, asdf movie, flip...
# 2                       US  flipnote, flipnote animation, asdf movie, flip...
# 3                       US  flipnote, flipnote animation, asdf movie, flip...
# 4                       US  flipnote, flipnote animation, asdf movie, flip...
# ...                    ...                                                ...
# 8061                    US  voodoo fries wingstop, this is not a veggie sa...
# 8062                    US  bakugou racism asmr, boyfriend asmr, funny asm...
# 8063                    US  fake awake by tarte, Tarte Cosmetics, tubing m...
# 8065                    US  Bk Beauty Brushes, bk beauty, concealer brush,...
# 8067                    US  Hozier, hozier sweatshirt, hozierofficial, Hoz...
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0           3500000.0           39500.0             10800.0       18700000.0
# 1           3500000.0           39500.0             10800.0       18700000.0
# 2           3500000.0           39500.0             10800.0       18700000.0
# 3           3500000.0           39500.0             10800.0       18700000.0
# 4           3500000.0           39500.0             10800.0       18700000.0
# ...               ...               ...                 ...              ...
# 8061          94000.0             719.0               180.0         783600.0
# 8062         893800.0           60500.0             21000.0        5800000.0
# 8063         107500.0            1162.0               521.0       18500000.0
# 8065          23200.0             113.0               205.0        1300000.0
# 8067         139400.0            3474.0               553.0        2700000.0
#
#                                       video_description  video_is_ad  \
# 0                                Bonus flipnote for you        False
# 1                                Bonus flipnote for you        False
# 2                                Bonus flipnote for you        False
# 3                                Bonus flipnote for you        False
# 4                                Bonus flipnote for you        False
# ...                                                 ...          ...
# 8061  this is not a veggie sandwhich. #wingstop #voo...        False
# 8062  Since apparently this is the only way i can ge...        False
# 8063  Replying to @Ashley Hunsucker The Tarte trio d...         True
# 8065  I’m a deal fiend, so I figured I would share. ...         True
# 8067  These lyrics are sunlight  #ilovehozier #hozie...        False
#
#       video_stickers          author_username      author_name  \
# 0                NaN          zanelittlemusic      Zane Little
# 1                NaN          zanelittlemusic      Zane Little
# 2                NaN          zanelittlemusic      Zane Little
# 3                NaN          zanelittlemusic      Zane Little
# 4                NaN          zanelittlemusic      Zane Little
# ...              ...                      ...              ...
# 8061             NaN  sellinglikeghostc00kies      Ella Sophia
# 8062             NaN                 iivoryss            ivory
# 8063             NaN             michellesays         Michelle
# 8065             NaN      itsmakeupbymelissam  Melissa Murdick
# 8067             NaN     melodyprints_theboys      HEVALLETTRE
#
#       author_followercount  author_followingcount  author_heartcount  \
# 0                      NaN                    NaN                NaN
# 1                      NaN                    NaN                NaN
# 2                      NaN                    NaN                NaN
# 3                      NaN                    NaN                NaN
# 4                      NaN                    NaN                NaN
# ...                    ...                    ...                ...
# 8061                   NaN                    NaN                NaN
# 8062                   NaN                    NaN                NaN
# 8063                   NaN                    NaN                NaN
# 8065                   NaN                    NaN                NaN
# 8067                   NaN                    NaN                NaN
#
#       author_videocount  author_diggcount  author_verified
# 0                   NaN               NaN            False
# 1                   NaN               NaN            False
# 2                   NaN               NaN            False
# 3                   NaN               NaN            False
# 4                   NaN               NaN            False
# ...                 ...               ...              ...
# 8061                NaN               NaN            False
# 8062                NaN               NaN            False
# 8063                NaN               NaN            False
# 8065                NaN               NaN             True
# 8067                NaN               NaN            False
#
# [5411 rows x 20 columns]

# %%
data_to_filter = data_to_filter.loc[data_to_filter['video_is_ad'] == False]

# %%
data_to_filter
# Out:
#                  video_id      video_timestamp  video_duration  \
# 0     7315561816673750318  2023-12-22T18:16:20            18.0
# 1     7315561816673750318  2023-12-22T18:16:20            18.0
# 2     7315561816673750318  2023-12-22T18:16:20            18.0
# 3     7315561816673750318  2023-12-22T18:16:20            18.0
# 4     7315561816673750318  2023-12-22T18:16:20            18.0
# ...                   ...                  ...             ...
# 8057  7337063556329803051  2024-02-18T16:54:05            38.0
# 8059  7337405612608720171  2024-02-19T15:01:32            46.0
# 8061  7336803062230601002  2024-02-18T00:03:29             8.0
# 8062  7337420660160875819  2024-02-19T15:59:58            34.0
# 8067  7328816594363338030  2024-01-27T11:31:50            45.0
#
#      video_locationcreated                                    suggested_words  \
# 0                       US  flipnote, flipnote animation, asdf movie, flip...
# 1                       US  flipnote, flipnote animation, asdf movie, flip...
# 2                       US  flipnote, flipnote animation, asdf movie, flip...
# 3                       US  flipnote, flipnote animation, asdf movie, flip...
# 4                       US  flipnote, flipnote animation, asdf movie, flip...
# ...                    ...                                                ...
# 8057                    US  Michaelrapaport, michael rapaport palestine, r...
# 8059                    US  Couple Comedy, couple, Couple TikTok, Couples ...
# 8061                    US  voodoo fries wingstop, this is not a veggie sa...
# 8062                    US  bakugou racism asmr, boyfriend asmr, funny asm...
# 8067                    US  Hozier, hozier sweatshirt, hozierofficial, Hoz...
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0           3500000.0           39500.0             10800.0       18700000.0
# 1           3500000.0           39500.0             10800.0       18700000.0
# 2           3500000.0           39500.0             10800.0       18700000.0
# 3           3500000.0           39500.0             10800.0       18700000.0
# 4           3500000.0           39500.0             10800.0       18700000.0
# ...               ...               ...                 ...              ...
# 8057         199500.0            3856.0              5668.0        1200000.0
# 8059         148800.0            2626.0              1055.0        1300000.0
# 8061          94000.0             719.0               180.0         783600.0
# 8062         893800.0           60500.0             21000.0        5800000.0
# 8067         139400.0            3474.0               553.0        2700000.0
#
#                                       video_description  video_is_ad  \
# 0                                Bonus flipnote for you        False
# 1                                Bonus flipnote for you        False
# 2                                Bonus flipnote for you        False
# 3                                Bonus flipnote for you        False
# 4                                Bonus flipnote for you        False
# ...                                                 ...          ...
# 8057  #greenscreenvideo the more things change the m...        False
# 8059  My husband does not approve this message.  #ma...        False
# 8061  this is not a veggie sandwhich. #wingstop #voo...        False
# 8062  Since apparently this is the only way i can ge...        False
# 8067  These lyrics are sunlight  #ilovehozier #hozie...        False
#
#       video_stickers          author_username       author_name  \
# 0                NaN          zanelittlemusic       Zane Little
# 1                NaN          zanelittlemusic       Zane Little
# 2                NaN          zanelittlemusic       Zane Little
# 3                NaN          zanelittlemusic       Zane Little
# 4                NaN          zanelittlemusic       Zane Little
# ...              ...                      ...               ...
# 8057             NaN           evann_with_2ns  Evann with 2 N's
# 8059             NaN        allisonraskinbaby    Allison Raskin
# 8061             NaN  sellinglikeghostc00kies       Ella Sophia
# 8062             NaN                 iivoryss             ivory
# 8067             NaN     melodyprints_theboys       HEVALLETTRE
#
#       author_followercount  author_followingcount  author_heartcount  \
# 0                      NaN                    NaN                NaN
# 1                      NaN                    NaN                NaN
# 2                      NaN                    NaN                NaN
# 3                      NaN                    NaN                NaN
# 4                      NaN                    NaN                NaN
# ...                    ...                    ...                ...
# 8057                   NaN                    NaN                NaN
# 8059                   NaN                    NaN                NaN
# 8061                   NaN                    NaN                NaN
# 8062                   NaN                    NaN                NaN
# 8067                   NaN                    NaN                NaN
#
#       author_videocount  author_diggcount  author_verified
# 0                   NaN               NaN            False
# 1                   NaN               NaN            False
# 2                   NaN               NaN            False
# 3                   NaN               NaN            False
# 4                   NaN               NaN            False
# ...                 ...               ...              ...
# 8057                NaN               NaN            False
# 8059                NaN               NaN            False
# 8061                NaN               NaN            False
# 8062                NaN               NaN            False
# 8067                NaN               NaN            False
#
# [5118 rows x 20 columns]

# %%
import re
def getHashtags(phrase):
    if isinstance(phrase, str):
        return re.findall(r'#(\S+)', phrase.lower())
    else:
        return []

data_to_filter['hashtags'] = data_to_filter['video_description'].apply(getHashtags)

def getSuggestedWords(phrase):
    if phrase is None:
        return []
    elif isinstance(phrase, str):
        return phrase.split(',')
    else:
        return []
    
data_to_filter['suggested_words'] = data_to_filter['suggested_words'].apply(getSuggestedWords)
# Out:
# /var/folders/s4/ppn80whx7vncf15l68hxt0tm0000gn/T/ipykernel_95562/1592711010.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_filter['hashtags'] = data_to_filter['video_description'].apply(getHashtags)
# /var/folders/s4/ppn80whx7vncf15l68hxt0tm0000gn/T/ipykernel_95562/1592711010.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_filter['suggested_words'] = data_to_filter['suggested_words'].apply(getSuggestedWords)

# %%
data_to_filter
# Out:
#                  video_id      video_timestamp  video_duration  \
# 0     7315561816673750318  2023-12-22T18:16:20            18.0
# 1     7315561816673750318  2023-12-22T18:16:20            18.0
# 2     7315561816673750318  2023-12-22T18:16:20            18.0
# 3     7315561816673750318  2023-12-22T18:16:20            18.0
# 4     7315561816673750318  2023-12-22T18:16:20            18.0
# ...                   ...                  ...             ...
# 8057  7337063556329803051  2024-02-18T16:54:05            38.0
# 8059  7337405612608720171  2024-02-19T15:01:32            46.0
# 8061  7336803062230601002  2024-02-18T00:03:29             8.0
# 8062  7337420660160875819  2024-02-19T15:59:58            34.0
# 8067  7328816594363338030  2024-01-27T11:31:50            45.0
#
#      video_locationcreated                                    suggested_words  \
# 0                       US  [flipnote,  flipnote animation,  asdf movie,  ...
# 1                       US  [flipnote,  flipnote animation,  asdf movie,  ...
# 2                       US  [flipnote,  flipnote animation,  asdf movie,  ...
# 3                       US  [flipnote,  flipnote animation,  asdf movie,  ...
# 4                       US  [flipnote,  flipnote animation,  asdf movie,  ...
# ...                    ...                                                ...
# 8057                    US  [Michaelrapaport,  michael rapaport palestine,...
# 8059                    US  [Couple Comedy,  couple,  Couple TikTok,  Coup...
# 8061                    US  [voodoo fries wingstop,  this is not a veggie ...
# 8062                    US  [bakugou racism asmr,  boyfriend asmr,  funny ...
# 8067                    US  [Hozier,  hozier sweatshirt,  hozierofficial, ...
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0           3500000.0           39500.0             10800.0       18700000.0
# 1           3500000.0           39500.0             10800.0       18700000.0
# 2           3500000.0           39500.0             10800.0       18700000.0
# 3           3500000.0           39500.0             10800.0       18700000.0
# 4           3500000.0           39500.0             10800.0       18700000.0
# ...               ...               ...                 ...              ...
# 8057         199500.0            3856.0              5668.0        1200000.0
# 8059         148800.0            2626.0              1055.0        1300000.0
# 8061          94000.0             719.0               180.0         783600.0
# 8062         893800.0           60500.0             21000.0        5800000.0
# 8067         139400.0            3474.0               553.0        2700000.0
#
#                                       video_description  ...  video_stickers  \
# 0                                Bonus flipnote for you  ...             NaN
# 1                                Bonus flipnote for you  ...             NaN
# 2                                Bonus flipnote for you  ...             NaN
# 3                                Bonus flipnote for you  ...             NaN
# 4                                Bonus flipnote for you  ...             NaN
# ...                                                 ...  ...             ...
# 8057  #greenscreenvideo the more things change the m...  ...             NaN
# 8059  My husband does not approve this message.  #ma...  ...             NaN
# 8061  this is not a veggie sandwhich. #wingstop #voo...  ...             NaN
# 8062  Since apparently this is the only way i can ge...  ...             NaN
# 8067  These lyrics are sunlight  #ilovehozier #hozie...  ...             NaN
#
#               author_username       author_name author_followercount  \
# 0             zanelittlemusic       Zane Little                  NaN
# 1             zanelittlemusic       Zane Little                  NaN
# 2             zanelittlemusic       Zane Little                  NaN
# 3             zanelittlemusic       Zane Little                  NaN
# 4             zanelittlemusic       Zane Little                  NaN
# ...                       ...               ...                  ...
# 8057           evann_with_2ns  Evann with 2 N's                  NaN
# 8059        allisonraskinbaby    Allison Raskin                  NaN
# 8061  sellinglikeghostc00kies       Ella Sophia                  NaN
# 8062                 iivoryss             ivory                  NaN
# 8067     melodyprints_theboys       HEVALLETTRE                  NaN
#
#       author_followingcount  author_heartcount  author_videocount  \
# 0                       NaN                NaN                NaN
# 1                       NaN                NaN                NaN
# 2                       NaN                NaN                NaN
# 3                       NaN                NaN                NaN
# 4                       NaN                NaN                NaN
# ...                     ...                ...                ...
# 8057                    NaN                NaN                NaN
# 8059                    NaN                NaN                NaN
# 8061                    NaN                NaN                NaN
# 8062                    NaN                NaN                NaN
# 8067                    NaN                NaN                NaN
#
#       author_diggcount  author_verified  \
# 0                  NaN            False
# 1                  NaN            False
# 2                  NaN            False
# 3                  NaN            False
# 4                  NaN            False
# ...                ...              ...
# 8057               NaN            False
# 8059               NaN            False
# 8061               NaN            False
# 8062               NaN            False
# 8067               NaN            False
#
#                                                hashtags
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 8057                                 [greenscreenvideo]
# 8059         [marriage, couplegoals, couplecomedy, fyp]
# 8061                 [wingstop, voodoofries, food, fyp]
# 8062  [asmr, gettingbeatwithapan, cute, coquette, fy...
# 8067  [ilovehozier, hozierlyrics, cherrywimehozier, ...
#
# [5118 rows x 21 columns]

# %%
def filter_conditions(row):
    has_hashtag = isinstance(row['hashtags'], list) and any(hashtag in row['hashtags'] for hashtag in hashtags_list)
    is_creator = row['author_username'] in creaters_list
    has_suggested_word = isinstance(row['suggested_words'], list) and any(word in row['suggested_words'] for word in hashtags_list)
    
    return has_hashtag or is_creator or has_suggested_word

data_to_filter_result = data_to_filter[data_to_filter.apply(filter_conditions, axis=1)]

## if hashtags is indeed a list, check if there is overlap between the video hashtag and the hashtag list or if the video 
## content creator is a news account. If any of the two is satisfied, pass to new dataset newsDF.

# %%
data_to_filter_result
## This result is actually a bit too weird

# %%
file_name = 'new_relevant_videos.csv' #change as needed
with open(file_name, 'w') as fout:
    data_to_filter_result.to_csv('news_relevant_videos_26301.csv')
