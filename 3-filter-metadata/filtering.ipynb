# %%
import pandas as pd

hashtags = pd.read_csv('news_hashtags.csv')
creaters = pd.read_csv('news_creaters.csv')

# %%
hashtags
hashtags_list = hashtags['Hashtag name'].tolist()

# %%
#hashtags_list

# %%
creaters
creaters_list = creaters['Username'].tolist()

# %%
#creaters_list

# %%
dir_path = "/Users/sandyliu/tiktok-news-exposure/" # CHANGE ME!

# %%
file_to_process = dir_path + "2-collect-metadata-pyktok/final-metadata/results_48271.csv"
data_to_filter = pd.read_csv(file_to_process) #change this line to parse different files
data_to_filter
# Out:
#                 video_id      video_timestamp  video_duration  \
# 0    7285457617009315105  2023-10-02T16:16:32             0.0
# 1    7283865333583088929  2023-09-28T09:17:42            46.0
# 2    7283836923393625377  2023-09-28T07:29:43            60.0
# 3    7267737378737966341  2023-08-15T22:12:55           190.0
# 4    7287677413025123615  2023-10-08T15:50:31            35.0
# ..                   ...                  ...             ...
# 583  7280374358101527840  2023-09-19T17:45:00           165.0
# 584  7273366749246967046  2023-08-31T02:17:45            66.0
# 585  7279732628268436769  2023-09-17T06:00:39            11.0
# 586  7279412251474316587  2023-09-16T09:17:39             0.0
# 587  7280444523203808554  2023-09-19T04:03:18           158.0
#
#     video_locationcreated                                    suggested_words  \
# 0                      DE                                                NaN
# 1                      GB  jake and amy, amy dork dance, brooklyn 99, jak...
# 2                      PL                                                NaN
# 3                      CA                                                NaN
# 4                      US                                                NaN
# ..                    ...                                                ...
# 583                    US                                                NaN
# 584                    MX                                                NaN
# 585                    TN                                                NaN
# 586                    US                                                NaN
# 587                    US  Pallas Cats, Cats Videos, Animal Videos, Anima...
#
#      video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0            98900.0          106700.0              2975.0        1900000.0
# 1           627800.0            2675.0               443.0        4700000.0
# 2            28900.0            4156.0               169.0         228400.0
# 3           784000.0           14600.0               697.0        3900000.0
# 4            45600.0            1335.0               114.0         673000.0
# ..               ...               ...                 ...              ...
# 583         323500.0            9782.0              3184.0        3200000.0
# 584           3022.0             146.0                33.0          52400.0
# 585         173800.0           19000.0              1369.0        1100000.0
# 586        1400000.0          351100.0             18900.0       10100000.0
# 587         113600.0            9421.0               582.0         852200.0
#
#                                      video_description  video_is_ad  \
# 0    #redthoughts #redthoughtsforhim #redthoughtsfo...        False
# 1    teddy vs jake, there’s just no competition #br...        False
# 2    2 INSANE CT FLASHES on CS2 MIRAGE #cs2 #cs2bet...        False
# 3    #theoffice #funny #noworkdone #foryou #fyp #th...        False
# 4    And believe it or not… the same price if not c...        False
# ..                                                 ...          ...
# 583  My Ex DUMPED Me to GET HER KITTY POUNDED by SW...        False
# 584      #cyphersetup #cyphervalorant #breezevalorant         False
# 585                    #tvshow #petergriffin #english         False
# 586  #fyp #foru #babykittenrizz #babykitten #kitten...        False
# 587                    #wildlife #kitten #cat #animal         False
#
#      video_stickers    author_username          author_name  \
# 0               NaN   red.thoughts2641        💋red thougts😏
# 1               NaN         brooklyn99   Brooklyn Nine-Nine
# 2               NaN      cs2_is_broken        cs2_is_broken
# 3               NaN  theofficebloopurs         bloopers.com
# 4               NaN        devourpower          DEVOURPOWER
# ..              ...                ...                  ...
# 583             NaN    reddits.stories     Reddit‘s Stories
# 584             NaN         yizuskrayz          Yizus Krayz
# 585             NaN  cartoonviralclips  funny cartoon clips
# 586             NaN      kitty.rizzler        Kitty Rizzler
# 587             NaN    animaltracks789        Animal Tracks
#
#      author_followercount  author_followingcount  author_heartcount  \
# 0                     NaN                    NaN                NaN
# 1                     NaN                    NaN                NaN
# 2                     NaN                    NaN                NaN
# 3                     NaN                    NaN                NaN
# 4                     NaN                    NaN                NaN
# ..                    ...                    ...                ...
# 583                   NaN                    NaN                NaN
# 584                   NaN                    NaN                NaN
# 585                   NaN                    NaN                NaN
# 586                   NaN                    NaN                NaN
# 587                   NaN                    NaN                NaN
#
#      author_videocount  author_diggcount  author_verified
# 0                  NaN               NaN            False
# 1                  NaN               NaN             True
# 2                  NaN               NaN            False
# 3                  NaN               NaN            False
# 4                  NaN               NaN             True
# ..                 ...               ...              ...
# 583                NaN               NaN            False
# 584                NaN               NaN            False
# 585                NaN               NaN            False
# 586                NaN               NaN            False
# 587                NaN               NaN            False
#
# [588 rows x 20 columns]

# %%
data_to_filter = data_to_filter.loc[data_to_filter['video_locationcreated'] == 'US']

# %%
data_to_filter
# Out:
#                 video_id      video_timestamp  video_duration  \
# 4    7287677413025123615  2023-10-08T15:50:31            35.0
# 5    7276098613892156705  2023-09-07T10:58:51            21.0
# 6    7287220444371881259  2023-10-07T10:17:23           303.0
# 7    7288375239770164522  2023-10-10T12:58:28             0.0
# 8    7288341455687503134  2023-10-10T10:47:22             6.0
# ..                   ...                  ...             ...
# 577  7279551375749467423  2023-09-16T18:17:26           162.0
# 579  7279124796749663534  2023-09-15T14:42:06           100.0
# 583  7280374358101527840  2023-09-19T17:45:00           165.0
# 586  7279412251474316587  2023-09-16T09:17:39             0.0
# 587  7280444523203808554  2023-09-19T04:03:18           158.0
#
#     video_locationcreated                                    suggested_words  \
# 4                      US                                                NaN
# 5                      US                                                NaN
# 6                      US                                                NaN
# 7                      US                                                NaN
# 8                      US                                                NaN
# ..                    ...                                                ...
# 577                    US                                                NaN
# 579                    US                                                NaN
# 583                    US                                                NaN
# 586                    US                                                NaN
# 587                    US  Pallas Cats, Cats Videos, Animal Videos, Anima...
#
#      video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 4            45600.0            1335.0               114.0         673000.0
# 5           190900.0           21200.0               852.0        4000000.0
# 6           196100.0             498.0               858.0        2900000.0
# 7             1559.0             618.0                 8.0          24800.0
# 8           356700.0           79500.0               607.0        2400000.0
# ..               ...               ...                 ...              ...
# 577         490400.0           27100.0               756.0        4300000.0
# 579          95500.0             235.0                53.0         954300.0
# 583         323500.0            9782.0              3184.0        3200000.0
# 586        1400000.0          351100.0             18900.0       10100000.0
# 587         113600.0            9421.0               582.0         852200.0
#
#                                      video_description  video_is_ad  \
# 4    And believe it or not… the same price if not c...        False
# 5    The End 🤣🤣 #funny #funnyvideos #animals #dog #...        False
# 6          Part1#storytime #foryou #story #fypシ゚viral         False
# 7      #fyp #memes #memestiktok #funny #meme #twitter         False
# 8                                                  NaN        False
# ..                                                 ...          ...
# 577                        P*ssy Navy Seals #navyseal         False
# 579                       #fyp #tiktok #movie #foryou         False
# 583  My Ex DUMPED Me to GET HER KITTY POUNDED by SW...        False
# 586  #fyp #foru #babykittenrizz #babykitten #kitten...        False
# 587                    #wildlife #kitten #cat #animal         False
#
#      video_stickers         author_username              author_name  \
# 4               NaN             devourpower              DEVOURPOWER
# 5               NaN  theminecracftassistant         Meme Minecracft🤩
# 6               NaN              storyspin1                StorySpin
# 7               NaN             ashlynjadeb                      ash
# 8               NaN   mcdonnelldouglas_f15e  McDonnell Douglas F-15E
# ..              ...                     ...                      ...
# 577             NaN       hustlerpotentiall         HUSTLERPOTENTIAL
# 579             NaN      user85615408784000                  Richard
# 583             NaN         reddits.stories         Reddit‘s Stories
# 586             NaN           kitty.rizzler            Kitty Rizzler
# 587             NaN         animaltracks789            Animal Tracks
#
#      author_followercount  author_followingcount  author_heartcount  \
# 4                     NaN                    NaN                NaN
# 5                     NaN                    NaN                NaN
# 6                     NaN                    NaN                NaN
# 7                     NaN                    NaN                NaN
# 8                     NaN                    NaN                NaN
# ..                    ...                    ...                ...
# 577                   NaN                    NaN                NaN
# 579                   NaN                    NaN                NaN
# 583                   NaN                    NaN                NaN
# 586                   NaN                    NaN                NaN
# 587                   NaN                    NaN                NaN
#
#      author_videocount  author_diggcount  author_verified
# 4                  NaN               NaN             True
# 5                  NaN               NaN            False
# 6                  NaN               NaN            False
# 7                  NaN               NaN            False
# 8                  NaN               NaN            False
# ..                 ...               ...              ...
# 577                NaN               NaN            False
# 579                NaN               NaN            False
# 583                NaN               NaN            False
# 586                NaN               NaN            False
# 587                NaN               NaN            False
#
# [355 rows x 20 columns]

# %%
data_to_filter = data_to_filter.loc[data_to_filter['video_is_ad'] == False]

# %%
data_to_filter
# Out:
#                 video_id      video_timestamp  video_duration  \
# 4    7287677413025123615  2023-10-08T15:50:31            35.0
# 5    7276098613892156705  2023-09-07T10:58:51            21.0
# 6    7287220444371881259  2023-10-07T10:17:23           303.0
# 7    7288375239770164522  2023-10-10T12:58:28             0.0
# 8    7288341455687503134  2023-10-10T10:47:22             6.0
# ..                   ...                  ...             ...
# 577  7279551375749467423  2023-09-16T18:17:26           162.0
# 579  7279124796749663534  2023-09-15T14:42:06           100.0
# 583  7280374358101527840  2023-09-19T17:45:00           165.0
# 586  7279412251474316587  2023-09-16T09:17:39             0.0
# 587  7280444523203808554  2023-09-19T04:03:18           158.0
#
#     video_locationcreated                                    suggested_words  \
# 4                      US                                                NaN
# 5                      US                                                NaN
# 6                      US                                                NaN
# 7                      US                                                NaN
# 8                      US                                                NaN
# ..                    ...                                                ...
# 577                    US                                                NaN
# 579                    US                                                NaN
# 583                    US                                                NaN
# 586                    US                                                NaN
# 587                    US  Pallas Cats, Cats Videos, Animal Videos, Anima...
#
#      video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 4            45600.0            1335.0               114.0         673000.0
# 5           190900.0           21200.0               852.0        4000000.0
# 6           196100.0             498.0               858.0        2900000.0
# 7             1559.0             618.0                 8.0          24800.0
# 8           356700.0           79500.0               607.0        2400000.0
# ..               ...               ...                 ...              ...
# 577         490400.0           27100.0               756.0        4300000.0
# 579          95500.0             235.0                53.0         954300.0
# 583         323500.0            9782.0              3184.0        3200000.0
# 586        1400000.0          351100.0             18900.0       10100000.0
# 587         113600.0            9421.0               582.0         852200.0
#
#                                      video_description  video_is_ad  \
# 4    And believe it or not… the same price if not c...        False
# 5    The End 🤣🤣 #funny #funnyvideos #animals #dog #...        False
# 6          Part1#storytime #foryou #story #fypシ゚viral         False
# 7      #fyp #memes #memestiktok #funny #meme #twitter         False
# 8                                                  NaN        False
# ..                                                 ...          ...
# 577                        P*ssy Navy Seals #navyseal         False
# 579                       #fyp #tiktok #movie #foryou         False
# 583  My Ex DUMPED Me to GET HER KITTY POUNDED by SW...        False
# 586  #fyp #foru #babykittenrizz #babykitten #kitten...        False
# 587                    #wildlife #kitten #cat #animal         False
#
#      video_stickers         author_username              author_name  \
# 4               NaN             devourpower              DEVOURPOWER
# 5               NaN  theminecracftassistant         Meme Minecracft🤩
# 6               NaN              storyspin1                StorySpin
# 7               NaN             ashlynjadeb                      ash
# 8               NaN   mcdonnelldouglas_f15e  McDonnell Douglas F-15E
# ..              ...                     ...                      ...
# 577             NaN       hustlerpotentiall         HUSTLERPOTENTIAL
# 579             NaN      user85615408784000                  Richard
# 583             NaN         reddits.stories         Reddit‘s Stories
# 586             NaN           kitty.rizzler            Kitty Rizzler
# 587             NaN         animaltracks789            Animal Tracks
#
#      author_followercount  author_followingcount  author_heartcount  \
# 4                     NaN                    NaN                NaN
# 5                     NaN                    NaN                NaN
# 6                     NaN                    NaN                NaN
# 7                     NaN                    NaN                NaN
# 8                     NaN                    NaN                NaN
# ..                    ...                    ...                ...
# 577                   NaN                    NaN                NaN
# 579                   NaN                    NaN                NaN
# 583                   NaN                    NaN                NaN
# 586                   NaN                    NaN                NaN
# 587                   NaN                    NaN                NaN
#
#      author_videocount  author_diggcount  author_verified
# 4                  NaN               NaN             True
# 5                  NaN               NaN            False
# 6                  NaN               NaN            False
# 7                  NaN               NaN            False
# 8                  NaN               NaN            False
# ..                 ...               ...              ...
# 577                NaN               NaN            False
# 579                NaN               NaN            False
# 583                NaN               NaN            False
# 586                NaN               NaN            False
# 587                NaN               NaN            False
#
# [353 rows x 20 columns]

# %%
import re
def getHashtags(phrase):
    if isinstance(phrase, str):
        return re.findall(r'#(\S+)', phrase.lower())
    else:
        return []

data_to_filter['hashtags'] = data_to_filter['video_description'].apply(getHashtags)

def getSuggestedWords(phrase):
    if phrase is None:
        return []
    elif isinstance(phrase, str):
        return phrase.split(',')
    else:
        return []
    
data_to_filter['suggested_words'] = data_to_filter['suggested_words'].apply(getSuggestedWords)
# Out:
# /var/folders/s4/ppn80whx7vncf15l68hxt0tm0000gn/T/ipykernel_39653/1592711010.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_filter['hashtags'] = data_to_filter['video_description'].apply(getHashtags)
# /var/folders/s4/ppn80whx7vncf15l68hxt0tm0000gn/T/ipykernel_39653/1592711010.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_filter['suggested_words'] = data_to_filter['suggested_words'].apply(getSuggestedWords)

# %%
data_to_filter
# Out:
#                 video_id      video_timestamp  video_duration  \
# 4    7287677413025123615  2023-10-08T15:50:31            35.0
# 5    7276098613892156705  2023-09-07T10:58:51            21.0
# 6    7287220444371881259  2023-10-07T10:17:23           303.0
# 7    7288375239770164522  2023-10-10T12:58:28             0.0
# 8    7288341455687503134  2023-10-10T10:47:22             6.0
# ..                   ...                  ...             ...
# 577  7279551375749467423  2023-09-16T18:17:26           162.0
# 579  7279124796749663534  2023-09-15T14:42:06           100.0
# 583  7280374358101527840  2023-09-19T17:45:00           165.0
# 586  7279412251474316587  2023-09-16T09:17:39             0.0
# 587  7280444523203808554  2023-09-19T04:03:18           158.0
#
#     video_locationcreated                                    suggested_words  \
# 4                      US                                                 []
# 5                      US                                                 []
# 6                      US                                                 []
# 7                      US                                                 []
# 8                      US                                                 []
# ..                    ...                                                ...
# 577                    US                                                 []
# 579                    US                                                 []
# 583                    US                                                 []
# 586                    US                                                 []
# 587                    US  [Pallas Cats,  Cats Videos,  Animal Videos,  A...
#
#      video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 4            45600.0            1335.0               114.0         673000.0
# 5           190900.0           21200.0               852.0        4000000.0
# 6           196100.0             498.0               858.0        2900000.0
# 7             1559.0             618.0                 8.0          24800.0
# 8           356700.0           79500.0               607.0        2400000.0
# ..               ...               ...                 ...              ...
# 577         490400.0           27100.0               756.0        4300000.0
# 579          95500.0             235.0                53.0         954300.0
# 583         323500.0            9782.0              3184.0        3200000.0
# 586        1400000.0          351100.0             18900.0       10100000.0
# 587         113600.0            9421.0               582.0         852200.0
#
#                                      video_description  ...  video_stickers  \
# 4    And believe it or not… the same price if not c...  ...             NaN
# 5    The End 🤣🤣 #funny #funnyvideos #animals #dog #...  ...             NaN
# 6          Part1#storytime #foryou #story #fypシ゚viral   ...             NaN
# 7      #fyp #memes #memestiktok #funny #meme #twitter   ...             NaN
# 8                                                  NaN  ...             NaN
# ..                                                 ...  ...             ...
# 577                        P*ssy Navy Seals #navyseal   ...             NaN
# 579                       #fyp #tiktok #movie #foryou   ...             NaN
# 583  My Ex DUMPED Me to GET HER KITTY POUNDED by SW...  ...             NaN
# 586  #fyp #foru #babykittenrizz #babykitten #kitten...  ...             NaN
# 587                    #wildlife #kitten #cat #animal   ...             NaN
#
#             author_username              author_name author_followercount  \
# 4               devourpower              DEVOURPOWER                  NaN
# 5    theminecracftassistant         Meme Minecracft🤩                  NaN
# 6                storyspin1                StorySpin                  NaN
# 7               ashlynjadeb                      ash                  NaN
# 8     mcdonnelldouglas_f15e  McDonnell Douglas F-15E                  NaN
# ..                      ...                      ...                  ...
# 577       hustlerpotentiall         HUSTLERPOTENTIAL                  NaN
# 579      user85615408784000                  Richard                  NaN
# 583         reddits.stories         Reddit‘s Stories                  NaN
# 586           kitty.rizzler            Kitty Rizzler                  NaN
# 587         animaltracks789            Animal Tracks                  NaN
#
#      author_followingcount  author_heartcount  author_videocount  \
# 4                      NaN                NaN                NaN
# 5                      NaN                NaN                NaN
# 6                      NaN                NaN                NaN
# 7                      NaN                NaN                NaN
# 8                      NaN                NaN                NaN
# ..                     ...                ...                ...
# 577                    NaN                NaN                NaN
# 579                    NaN                NaN                NaN
# 583                    NaN                NaN                NaN
# 586                    NaN                NaN                NaN
# 587                    NaN                NaN                NaN
#
#      author_diggcount  author_verified  \
# 4                 NaN             True
# 5                 NaN            False
# 6                 NaN            False
# 7                 NaN            False
# 8                 NaN            False
# ..                ...              ...
# 577               NaN            False
# 579               NaN            False
# 583               NaN            False
# 586               NaN            False
# 587               NaN            False
#
#                                               hashtags
# 4    [devourpower, fyp, foryou, foodtiktok, crownhe...
# 5    [funny, funnyvideos, animals, dog, cat, pet, v...
# 6               [storytime, foryou, story, fypシ゚viral]
# 7      [fyp, memes, memestiktok, funny, meme, twitter]
# 8                                                   []
# ..                                                 ...
# 577                                         [navyseal]
# 579                       [fyp, tiktok, movie, foryou]
# 583  [reddit, redditstories, redditreadings, askred...
# 586  [fyp, foru, babykittenrizz, babykitten, kitten...
# 587                    [wildlife, kitten, cat, animal]
#
# [353 rows x 21 columns]

# %%
def filter_conditions(row):
    has_hashtag = isinstance(row['hashtags'], list) and any(hashtag in row['hashtags'] for hashtag in hashtags_list)
    is_creator = row['author_username'] in creaters_list
    has_suggested_word = isinstance(row['suggested_words'], list) and any(word in row['suggested_words'] for word in hashtags_list)
    
    return has_hashtag or is_creator or has_suggested_word

data_to_filter_result = data_to_filter[data_to_filter.apply(filter_conditions, axis=1)]

## if hashtags is indeed a list, check if there is overlap between the video hashtag and the hashtag list or if the video 
## content creator is a news account. If any of the two is satisfied, pass to new dataset newsDF.

# %%
data_to_filter_result
## This result is actually a bit too weird
# Out:
#                 video_id      video_timestamp  video_duration  \
# 144  7285749180025408811  2023-10-03T14:30:00            41.0
# 183  7280588242024402218  2023-09-19T13:22:27            62.0
# 247  7282169818021645610  2023-09-23T19:38:12           205.0
# 252  7284389787144916270  2023-09-29T19:13:46           103.0
# 493  7281629597169405226  2023-09-22T08:41:53           132.0
# 524  7281705059778383147  2023-09-22T13:34:48            34.0
#
#     video_locationcreated                                    suggested_words  \
# 144                    US  [bogo sort,  Bubble Sort,  sorting algorithms,...
# 183                    US                                                 []
# 247                    US                                                 []
# 252                    US                                                 []
# 493                    US                                                 []
# 524                    US  [bedford high school,  bedford high school tra...
#
#      video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 144         740300.0           18800.0              4338.0       10400000.0
# 183         397600.0          393700.0             33900.0       11700000.0
# 247         565800.0            2801.0              3842.0        8200000.0
# 252        1300000.0          299500.0             91100.0       12500000.0
# 493          98700.0            3097.0               992.0        1100000.0
# 524         410800.0           67400.0              9383.0        3500000.0
#
#                                      video_description  ...  video_stickers  \
# 144  #quicksort #mergesort #sorting #algorithms #vi...  ...             NaN
# 183  Facts that could save your life‼️ | Part 11 | ...  ...             NaN
# 247  #fypシ #cops #foryou #cps #fyp #911 #police #ne...  ...             NaN
# 252  Video shows the events leading up to the shoot...  ...             NaN
# 493  Conway is amazing #math #learnontiktok #stem #...  ...             NaN
# 524  Disciplinary action is still being discussed, ...  ...             NaN
#
#         author_username     author_name author_followercount  \
# 144  sort_everything176     sort_vizual                  NaN
# 183        factsfromnez             Nez                  NaN
# 247            jeam5389      CRAZY COPS                  NaN
# 252       nbcwashington  NBC Washington                  NaN
# 493     average_joe_mcc     Average Joe                  NaN
# 524         nbc10boston    NBC10 Boston                  NaN
#
#      author_followingcount  author_heartcount  author_videocount  \
# 144                    NaN                NaN                NaN
# 183                    NaN                NaN                NaN
# 247                    NaN                NaN                NaN
# 252                    NaN                NaN                NaN
# 493                    NaN                NaN                NaN
# 524                    NaN                NaN                NaN
#
#      author_diggcount  author_verified  \
# 144               NaN            False
# 183               NaN            False
# 247               NaN            False
# 252               NaN             True
# 493               NaN            False
# 524               NaN             True
#
#                                               hashtags
# 144  [quicksort, mergesort, sorting, algorithms, vi...
# 183  [curiosity, randomfacts, learnontiktok, factsy...
# 247  [fypシ, cops, foryou, cps, fyp, 911, police, ne...
# 252  [dc, washingtondc, districtofcolumbia, dmvnews...
# 493  [math, learnontiktok, stem, science, mathteacher]
# 524           [newhampshire, school, news, video, fyp]
#
# [6 rows x 21 columns]

# %%
file_name = 'new_relevant_videos.csv' #change as needed
with open(file_name, 'w') as fout:
    data_to_filter_result.to_csv('news_relevant_videos_48271.csv')
