# %%
import pandas as pd

hashtags = pd.read_csv('news_hashtags.csv')
creaters = pd.read_csv('news_creaters.csv')

# %%
hashtags
hashtags_list = hashtags['Hashtag name'].tolist()

# %%
hashtags_list
# Out:
# ['uspolitics',
#  'republicans',
#  'republican',
#  'democrat',
#  'democrats',
#  'liberal',
#  'politics',
#  'politicaltiktok',
#  '2024election',
#  '2024president',
#  'news',
#  'breakingnews',
#  'conservative',
#  'immigration',
#  'bordercrisis',
#  'ukraine',
#  'palestine',
#  'gaza',
#  'election',
#  'trump',
#  'biden',
#  'covid',
#  'economy',
#  'breakingnews',
#  'journalism',
#  'worldnews',
#  'economics',
#  'FederalReserve',
#  'leftist',
#  'liberalism',
#  'trump2024',
#  'newstiktok',
#  '2024election',
#  'newsattiktok',
#  'noticiastiktok',
#  'noticiasen1minuto',
#  'noticias',
#  'newsupdate',
#  'inflation',
#  'chinesepolitics',
#  'climatechange',
#  'climategoals',
#  'currentnews',
#  'governmentshutdown',
#  'learnontiktok',
#  'trumptrial',
#  'historytok',
#  'trumprally',
#  'nato',
#  'trump',
#  'crime',
#  'michigan',
#  'conservative',
#  'rightwing',
#  'vote',
#  'fake news',
#  'ballot',
#  'israel',
#  'usapolitics',
#  'usaelections',
#  'uselections',
#  'joebiden',
#  '2024debate',
#  'hamas',
#  'crimetok',
#  'breaking',
#  'climate',
#  'supremecourt',
#  'politics',
#  'abortion',
#  'unemployment',
#  'ceasefire',
#  'protests',
#  'internationalnews ',
#  'usnews',
#  'pandemic',
#  'vaccines',
#  'technews',
#  'liveupdates',
#  'topstories',
#  'newsalert',
#  'blacklivesmatter',
#  'mediawatch',
#  'PoliticalCommentary',
#  'palestine',
#  'berita',
#  'worldnews',
#  'trump2024',
#  'election2024',
#  'yahoonews',
#  'abcnews',
#  'russia',
#  'scotus',
#  'thedemocrats',
#  'breakingnews',
#  'currentevents',
#  'uknews',
#  'goodnews',
#  '新闻',
#  'أخبار',
#  '参議院',
#  'aktualności',
#  'новости',
#  'unitednations',
#  'quicknews',
#  'fashionnews',
#  'houseofrepresentatives',
#  'cnbc',
#  'cnn',
#  'constitution',
#  'foxnews',
#  'msnbc',
#  'putin',
#  'tiktokでニュース',
#  'oregonnews',
#  'localnews',
#  'geonews',
#  'healthnews',
#  'breakingnewsalert',
#  'breakingnews2024',
#  '2024breakingnews',
#  'nbcnews',
#  'abcnews',
#  'NewsTok',
#  'viralnews',
#  'militarynews ',
#  'trendingnews',
#  'newsweek',
#  'congress',
#  'townhall',
#  'supertuesday',
#  'reproductiverights',
#  'netanyahu',
#  'stateoftheunion',
#  'newsafrica',
#  'kenyanews',
#  'elections2022🇰🇪',
#  'azimio',
#  'citizentvkenya',
#  'oscars',
#  'sports',
#  'football',
#  'internationalwomensday',
#  'police',
#  'nyt',
#  'nytimes']

# %%
creaters
creaters_list = creaters['Username'].tolist()

# %%
creaters_list
# Out:
# ['nytimes',
#  'washingtonpost',
#  'cnn',
#  'pbsnews',
#  'abcnews',
#  'msnbc',
#  'cbsnews',
#  'briantylercohen',
#  'cbseveningnews',
#  'abcworldnews',
#  'nbcnews',
#  'yahoonews',
#  '7newsq',
#  nan,
#  'skynews',
#  'bbc',
#  'forbes',
#  'usatoday',
#  'gbnews',
#  'varietymagazine',
#  'sophiasmithgaler',
#  'maxfostercnn',
#  'nytopinion',
#  '60minutes',
#  'cbsmornings',
#  'cbssundaymorning',
#  'vicenews',
#  'abcnewslive',
#  'gma',
#  'newsweek',
#  'underthedesknews',
#  'theconversation',
#  'nowthisimpact ',
#  'dailymail',
#  'davebondy',
#  'aljazeeraenglish',
#  'vicenewsdocs',
#  'c4news',
#  'itvnews',
#  'niickjackson',
#  'abc7la',
#  'reuters',
#  'npr',
#  'nowthis',
#  'brutamerica',
#  'thetelegraph',
#  'vox',
#  'buzzfeednews',
#  'taylorlorenz',
#  'wallstreetjournal',
#  'latimes',
#  'natgeo',
#  'vicderbyshire',
#  'pinknews',
#  'eveningstandard',
#  'cleoabram',
#  'sandragathmann',
#  'tldrnews',
#  'morningbrew',
#  'semafor',
#  'thepocketreport',
#  'theeconomist',
#  'thegarbagequeen',
#  'nbcnightlynews',
#  'benjaminzamoratven',
#  'thenewsmovement',
#  'elliecolts',
#  'gullyburrows',
#  'jacksurfleet ',
#  'washingtonpostlive',
#  'washingtonpostwellbeing',
#  'nbc.news_us',
#  'bbcnews ',
#  'cbcnews',
#  'radiodisney ',
#  'enews ',
#  'goodmorningbadnews',
#  'newus197655',
#  'catchupnews',
#  'nbc10boston',
#  'realandyhidalgo',
#  'homelandscanner',
#  'meganhealytv',
#  'Nehagohil.24',
#  'clogrifff',
#  'abbiedewhurst',
#  'jennalynn468',
#  'dylan.page',
#  'jamesgetspolitical',
#  'js.news17',
#  'metro_tv',
#  'republikaonline',
#  'liputan6.sctv',
#  'khaosodonline',
#  'thairath_news',
#  'tv_asahi_news',
#  'thaipbsnews',
#  '501awani',
#  'vicenews',
#  'thesun',
#  'georgia_coan',
#  'amandadcnn',
#  'katiepolglasecnn',
#  'vandamcnn',
#  'maddowshow',
#  'guardian',
#  'openlynews',
#  'chris.ship.royal',
#  'franceswangtv',
#  'jaketapper',
#  'gadischwartz',
#  'staytunednbc',
#  'watchsavannah',
#  'theatlantic',
#  'newyorker',
#  'huffpost',
#  'buzzfeednow',
#  'huffpostuk',
#  'phillyinquirer',
#  'newsday.tv ',
#  'citizen.digital',
#  'ntvkenya',
#  'habari_njema',
#  'tiin.worldnews ',
#  'aljazeera',
#  'newsnexussa',
#  '2nacheki',
#  'dw24tv',
#  'dailyglobalnewsshorts',
#  'royalnewschannel',
#  'update_438',
#  'rbarwanda',
#  'igihe',
#  'newschannelakp',
#  'leoandroccosounds',
#  'breakingnews1134',
#  'nigeriaglobalnews',
#  'newtimesrwanda',
#  'infos.minutes',
#  'unvelingtruth945',
#  'todayshow',
#  'nbcsports',
#  'nfl',
#  'therecount',
#  'bnc_news',
#  'thebryanjun',
#  'todayonline',
#  'news.daily4',
#  'todaysworldnews',
#  'newsworld5555',
#  'durikoreannews',
#  'thomasgermain',
#  'speedifylive',
#  'bernardgarby',
#  'thestanzamedia',
#  'thefacemagazine',
#  'plasticsnews',
#  'nownownews',
#  'thegoodnews100',
#  'sambentley',
#  'latinus_us',
#  'dallasmorningnews',
#  'bostonglobe',
#  'globeopinion',
#  'bostonglobetoday ',
#  'espn',
#  'time',
#  'skysports',
#  'skysportswsl',
#  'geonews',
#  '11thhourmsnbc',
#  'bolnews',
#  'cgtneurope',
#  'scmp.news',
#  'peoplesdaily',
#  'middleeasteye',
#  'businessinsider',
#  'cmlvancover',
#  'apnews',
#  'btnewsroom',
#  'trtworld ',
#  'cspanofficial',
#  'trtarabi',
#  'bloomberg',
#  'bloombergpolitics',
#  'bloombergbusiness',
#  'politicomx',
#  'foxnewsanytime',
#  'bostondotcom',
#  'abc7chicago',
#  'vox_espana',
#  'bloombergopinion',
#  'bloomberglaw',
#  'catoinstitute',
#  'startribune',
#  'johannaruediger',
#  'euronews.tv',
#  'bbcnewsbrasil',
#  'geonewsheadlines.pk',
#  '9news',
#  'news_389_us',
#  'news.show.h24',
#  'vtcnews',
#  'gmanews',
#  'kbc_news',
#  'orient_newsar',
#  'daily.news65',
#  'newsnationnow',
#  'ch7hd_news',
#  'us.breakingnews',
#  'arynews.official ',
#  'empact_news',
#  'newsguy38',
#  'real.benshapiro',
#  'joepags',
#  'newbreaking20231',
#  'vicenews',
#  'univision',
#  'therealisticfishhead',
#  'bbcnewsmundo',
#  'marcus.dipaola',
#  'businessinsideres',
#  'businessinsiderfr',
#  'businessinsidermx',
#  'yahoofinance',
#  'yahoobrasil',
#  'yahoouk',
#  'yahooaustralia',
#  'yahoosea',
#  'worldeconomicforum',
#  'wired',
#  'who',
#  'voguemagazine',
#  'voguegermany',
#  'vogueitalia',
#  'vice_spain',
#  'thestarmalaysia',
#  'nypost',
#  'asianewschannels',
#  'theetinalove',
#  'worldnewstoday2024',
#  'worldnewscoverage',
#  'worldlymap',
#  'msnbc',
#  'dailymirror',
#  'the.discloser',
#  'newweather1',
#  'news.tracking',
#  'facethenation',
#  'kellermankomedy',
#  'tedtok',
#  'ahhhamdan',
#  'wffnews',
#  'tonynew1501',
#  'abc7ny',
#  'abc13houston',
#  '6abcactionews',
#  'fox29philadelphia',
#  'fox2detroitwjbk',
#  'fox5_atlanta',
#  'wesh2orlando',
#  'nbcchicago',
#  'nbcwashington',
#  'washingtonianmag',
#  'ksatnews',
#  'wbznewsradio',
#  'b25news\n',
#  'rtenews',
#  'rocanews',
#  'freeda_en ',
#  'lanacioncom',
#  '\nsomegoodnewsofficial',
#  'thewellesleynews',
#  'dnews247',
#  'nasnewsdaily',
#  'siamnews',
#  'dzrhnews',
#  'joshhelfgott',
#  'pulselivekenya',
#  'ajplus',
#  'valerisssh',
#  '48hourscbs',
#  'kellermankomedy',
#  'usnews',
#  'newsfash',
#  'consumerreports',
#  'sustainableliz_',
#  'errol.barnett',
#  'reamichellew',
#  'planetmoney',
#  'kylascan',
#  'gingerzee',
#  'itsrachelscott',
#  'mynytimes',
#  'nytopinion',
#  'theathletic ',
#  'motherboardvice',
#  'zarahsultanamp',
#  'hanakomontgomery',
#  'viceontv',
#  'viceenespanol',
#  'uninoticias',
#  'future_explored',
#  'weisstech',
#  'tech.news3',
#  'mbtechnews',
#  'daily.tech.news',
#  'dailynewsonline',
#  'batamnews',
#  'deutschlandnews2',
#  'jovempannews',
#  'hypenews.ru',
#  'theglobalworldnews',
#  '3plusnews',
#  'sindonews',
#  'womannews.vn',
#  'chinanewsservice',
#  'cincainews',
#  'newstify',
#  'kompastvnews',
#  'livenews64',
#  'news_livesa',
#  'wereportnews',
#  'tribunnewssultraofficial',
#  'independennews.com',
#  'malaysianupdatenews',
#  'alarabytvnews',
#  'morningnewsch3',
#  'hygonews',
#  'bleacherreport',
#  'nessadiosdado',
#  'crimedivewithjess2.0',
#  'hebewiththenews',
#  'dailyfishtoknews',
#  'thedailydripmedia',
#  'thatgoodnewsgirl',
#  'newsninja',
#  'chroniclesofolivia',
#  'sbsnews_au',
#  'mustsharenews',
#  'luxinews',
#  'filonews',
#  'tribunkaltim.co',
#  'ctvnews',
#  'matta_of_fact',
#  'serranewsrj',
#  'visi.news',
#  'astrogempak',
#  'abc30_actionnews',
#  'abc7newsbayarea',
#  'abc7chicago',
#  '6abcactionnews',
#  'abc7ny',
#  'gma',
#  'kbsnewsofficial',
#  'sbsnews',
#  'kjmbc_news',
#  'bbcnews',
#  'sbsnews_au',
#  'mbs.news',
#  'mtvnews',
#  'knxnews',
#  'jtbcnews_official',
#  'ytnnews',
#  'oscars',
#  'abcnewslive',
#  'abcgma3',
#  'abc13houston',
#  'benjaminzamoratven\r',
#  'accuweather',
#  'manchesternews',
#  'lawandcrime',
#  '48hourscbs',
#  'insideedition',
#  'thomasrhanson',
#  'norahodonnell',
#  'nowthisearth',
#  'mehdihasanshow',
#  'reidout',
#  'katiephang',
#  'watchsavannah',
#  'meetthePress',
#  'niikjackson',
#  'aljazeeraenglish',
#  'bloombergpolitics',
#  'wordlymap',
#  'utusantvofficial',
#  'underthedesknews',
#  'charlesmblow',
#  'bbcsport',
#  'hollywoodreporter',
#  'omarjimeneztok',
#  'mayaeaglin',
#  'laurajarrettnbc',
#  'craigmelvinnbc',
#  'arimelber',
#  'andykaczynski',
#  'hodaandjenna',
#  'nbcsandiego',
#  'jenpsaki',
#  'tomllamasnbc',
#  'tvkatesnow',
#  'journalsentinel',
#  'nbcnewyork',
#  'nbcsouthflorida',
#  'nbcbayarea',
#  'nbcconnecticut',
#  'nbcla',
#  'vnexpress.international',
#  'vietnamnews.official',
#  'nextshark',
#  'insight_official',
#  'insight_fashion',
#  'insight_beauty',
#  'insight_food',
#  'starnewskorea',
#  'subusunews.official',
#  'yonhapnews',
#  'weathernewslive',
#  'youkhino',
#  'news_cool',
#  'officialinews',
#  'ntv.news',
#  'news_postseven',
#  'ktlanews',
#  '5wcvb',
#  'news5everywhere',
#  'newscientist']

# %%
dir_path = "/Users/sandyliu/tiktok-news-exposure/" # CHANGE ME!

# %%
file_to_process = dir_path + "2-collect-metadata-pyktok/final-metadata/RB-chunks/RB_chunk_5_metadata.csv"
data_to_filter = pd.read_csv(file_to_process) #change this line to parse different files
data_to_filter
# Out:
#                  video_id      video_timestamp  video_duration  \
# 0     7320748786752474410  2024-01-05T17:44:41            15.0
# 1     7321968197463248170  2024-01-09T00:36:54            21.0
# 2     7321970381856705834  2024-01-09T00:45:10            60.0
# 3     7321920939686382879  2024-01-08T21:33:22            60.0
# 4     7317406562312654123  2023-12-27T17:34:49            10.0
# ...                   ...                  ...             ...
# 9219  7314770274568719649  2023-12-20T15:04:49            27.0
# 9220  7315603495388728578  2023-12-22T20:57:55            16.0
# 9221  7313600768324406570  2023-12-17T11:26:30            25.0
# 9222  7318049044440354081  2023-12-29T11:08:03             0.0
# 9223  7316270172153646369  2023-12-24T16:04:58            74.0
#
#      video_locationcreated                                    suggested_words  \
# 0                       US  usc, usc neighborhood, lorenzo apartment usc, ...
# 1                       US                                                NaN
# 2                       US  2016 chino hills, cade cunningham, cade and em...
# 3                       US  williamson dad, oaklynn and truth, twins, Twin...
# 4                       US  parrot talking, Kiwi The Bird, thank you babes...
# ...                    ...                                                ...
# 9219                    NO  13 going on 30, Jennifer Garner, 13 going 30 e...
# 9220               FAKE-AD  Hair Products, hair care products, Products Fo...
# 9221                    US                                                NaN
# 9222                    GB                                                NaN
# 9223                    GB  Jim Parsons, Home Movie, jim parsons rihanna, ...
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0             92200.0            2051.0               567.0         727500.0
# 1             96100.0             575.0               716.0         823700.0
# 2            553500.0            2194.0              3377.0        5100000.0
# 3            731300.0            3230.0              1970.0        3900000.0
# 4           3500000.0          209400.0             18800.0       18700000.0
# ...               ...               ...                 ...              ...
# 9219         998100.0            6177.0              2651.0        5200000.0
# 9220            633.0              12.0                 1.0        5500000.0
# 9221          60600.0             267.0               243.0         325000.0
# 9222          22100.0              36.0                66.0         224100.0
# 9223         743400.0            1282.0               751.0        3700000.0
#
#                                       video_description  video_is_ad  \
# 0     Move-in with me #fyp#fypシ #apartmenttour #usc ...        False
# 1                 real. #trentejones #umich #relatable         False
# 2     Cade and em #cadecunningham #scottiebarnes #mo...        False
# 3     Truthy’s twin radar was going off. They werent...        False
# 4     babe, babe, babe 🤣💙 #indianringneck #talkingpa...        False
# ...                                                 ...          ...
# 9219  they're my roman empire. #13going30 #13goingon...        False
# 9220  Discover these bondbar™ products designed to r...         True
# 9221  the w in white house stands for women #oliviap...        False
# 9222       #montelljordan #thisishowwedoit #song #music        False
# 9223  The press interviews for this movie are gold 🤣...        False
#
#       video_stickers    author_username        author_name  \
# 0                NaN       mrblakeberry              Blake
# 1                NaN        trentejones                  T
# 2                NaN      shifty.elhajj       ShiftyElhajj
# 3                NaN   thewilliamsonfam  Da’ana Williamson
# 4                NaN         thebluerio       The Blue Rio
# ...              ...                ...                ...
# 9219             NaN       amn3siahours       𝐀𝐦𝐧𝟑𝐬𝐢𝐚𝐡𝐨𝐮𝐫𝐬
# 9220             NaN       Sally Beauty       Sally Beauty
# 9221             NaN           cateslou               jay🥀
# 9222             NaN          hotjamz4u    Hot Jamz 4 U 🔥🎶
# 9223             NaN  hallebaileysangel  hallebaileysangel
#
#       author_followercount  author_followingcount  author_heartcount  \
# 0                      NaN                    NaN                NaN
# 1                      NaN                    NaN                NaN
# 2                      NaN                    NaN                NaN
# 3                      NaN                    NaN                NaN
# 4                      NaN                    NaN                NaN
# ...                    ...                    ...                ...
# 9219                   NaN                    NaN                NaN
# 9220                   NaN                    NaN                NaN
# 9221                   NaN                    NaN                NaN
# 9222                   NaN                    NaN                NaN
# 9223                   NaN                    NaN                NaN
#
#       author_videocount  author_diggcount  author_verified
# 0                   NaN               NaN            False
# 1                   NaN               NaN             True
# 2                   NaN               NaN            False
# 3                   NaN               NaN            False
# 4                   NaN               NaN            False
# ...                 ...               ...              ...
# 9219                NaN               NaN            False
# 9220                NaN               NaN            False
# 9221                NaN               NaN            False
# 9222                NaN               NaN            False
# 9223                NaN               NaN            False
#
# [9224 rows x 20 columns]

# %%
import re
def getHashtags(phrase):
    if isinstance(phrase, str):
        return re.findall(r'#(\S+)', phrase.lower())
    else:
        return []

data_to_filter['hashtags'] = data_to_filter['video_description'].apply(getHashtags)
data_to_filter
# Out:
#                  video_id      video_timestamp  video_duration  \
# 0     7320748786752474410  2024-01-05T17:44:41            15.0
# 1     7321968197463248170  2024-01-09T00:36:54            21.0
# 2     7321970381856705834  2024-01-09T00:45:10            60.0
# 3     7321920939686382879  2024-01-08T21:33:22            60.0
# 4     7317406562312654123  2023-12-27T17:34:49            10.0
# ...                   ...                  ...             ...
# 9219  7314770274568719649  2023-12-20T15:04:49            27.0
# 9220  7315603495388728578  2023-12-22T20:57:55            16.0
# 9221  7313600768324406570  2023-12-17T11:26:30            25.0
# 9222  7318049044440354081  2023-12-29T11:08:03             0.0
# 9223  7316270172153646369  2023-12-24T16:04:58            74.0
#
#      video_locationcreated                                    suggested_words  \
# 0                       US  usc, usc neighborhood, lorenzo apartment usc, ...
# 1                       US                                                NaN
# 2                       US  2016 chino hills, cade cunningham, cade and em...
# 3                       US  williamson dad, oaklynn and truth, twins, Twin...
# 4                       US  parrot talking, Kiwi The Bird, thank you babes...
# ...                    ...                                                ...
# 9219                    NO  13 going on 30, Jennifer Garner, 13 going 30 e...
# 9220               FAKE-AD  Hair Products, hair care products, Products Fo...
# 9221                    US                                                NaN
# 9222                    GB                                                NaN
# 9223                    GB  Jim Parsons, Home Movie, jim parsons rihanna, ...
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0             92200.0            2051.0               567.0         727500.0
# 1             96100.0             575.0               716.0         823700.0
# 2            553500.0            2194.0              3377.0        5100000.0
# 3            731300.0            3230.0              1970.0        3900000.0
# 4           3500000.0          209400.0             18800.0       18700000.0
# ...               ...               ...                 ...              ...
# 9219         998100.0            6177.0              2651.0        5200000.0
# 9220            633.0              12.0                 1.0        5500000.0
# 9221          60600.0             267.0               243.0         325000.0
# 9222          22100.0              36.0                66.0         224100.0
# 9223         743400.0            1282.0               751.0        3700000.0
#
#                                       video_description  ...  video_stickers  \
# 0     Move-in with me #fyp#fypシ #apartmenttour #usc ...  ...             NaN
# 1                 real. #trentejones #umich #relatable   ...             NaN
# 2     Cade and em #cadecunningham #scottiebarnes #mo...  ...             NaN
# 3     Truthy’s twin radar was going off. They werent...  ...             NaN
# 4     babe, babe, babe 🤣💙 #indianringneck #talkingpa...  ...             NaN
# ...                                                 ...  ...             ...
# 9219  they're my roman empire. #13going30 #13goingon...  ...             NaN
# 9220  Discover these bondbar™ products designed to r...  ...             NaN
# 9221  the w in white house stands for women #oliviap...  ...             NaN
# 9222       #montelljordan #thisishowwedoit #song #music  ...             NaN
# 9223  The press interviews for this movie are gold 🤣...  ...             NaN
#
#         author_username        author_name author_followercount  \
# 0          mrblakeberry              Blake                  NaN
# 1           trentejones                  T                  NaN
# 2         shifty.elhajj       ShiftyElhajj                  NaN
# 3      thewilliamsonfam  Da’ana Williamson                  NaN
# 4            thebluerio       The Blue Rio                  NaN
# ...                 ...                ...                  ...
# 9219       amn3siahours       𝐀𝐦𝐧𝟑𝐬𝐢𝐚𝐡𝐨𝐮𝐫𝐬                  NaN
# 9220       Sally Beauty       Sally Beauty                  NaN
# 9221           cateslou               jay🥀                  NaN
# 9222          hotjamz4u    Hot Jamz 4 U 🔥🎶                  NaN
# 9223  hallebaileysangel  hallebaileysangel                  NaN
#
#       author_followingcount  author_heartcount  author_videocount  \
# 0                       NaN                NaN                NaN
# 1                       NaN                NaN                NaN
# 2                       NaN                NaN                NaN
# 3                       NaN                NaN                NaN
# 4                       NaN                NaN                NaN
# ...                     ...                ...                ...
# 9219                    NaN                NaN                NaN
# 9220                    NaN                NaN                NaN
# 9221                    NaN                NaN                NaN
# 9222                    NaN                NaN                NaN
# 9223                    NaN                NaN                NaN
#
#       author_diggcount  author_verified  \
# 0                  NaN            False
# 1                  NaN             True
# 2                  NaN            False
# 3                  NaN            False
# 4                  NaN            False
# ...                ...              ...
# 9219               NaN            False
# 9220               NaN            False
# 9221               NaN            False
# 9222               NaN            False
# 9223               NaN            False
#
#                                                hashtags
# 0       [fyp#fypシ, apartmenttour, usc, movein, college]
# 1                       [trentejones, umich, relatable]
# 2     [cadecunningham, scottiebarnes, montverde, mon...
# 3                                                    []
# 4     [indianringneck, talkingparrot, iloveyou, love...
# ...                                                 ...
# 9219  [13going30, 13goingon30edit, jennifergarner, j...
# 9220                                                 []
# 9221  [oliviapope, melliegrant, mellivia, scandal, k...
# 9222      [montelljordan, thisishowwedoit, song, music]
# 9223  [rihanna, riri, jimparsons, funny, funnyvideos...
#
# [9224 rows x 21 columns]

# %%
newsDF = data_to_filter[data_to_filter.apply(lambda row: 
                      (isinstance(row['hashtags'], list) and 
                       any(hashtag in row['hashtags'] for hashtag in hashtags_list)) 
                      or row['author_username'] in creaters_list, axis=1)]

## if hashtags is indeed a list, check if there is overlap between the video hashtag and the hashtag list or if the video 
## content creator is a news account. If any of the two is satisfied, pass to new dataset newsDF.

# %%
newsDF
## This result is actually a bit too weird
# Out:
#                  video_id      video_timestamp  video_duration  \
# 8     7322192502713535790  2024-01-09T15:06:54           182.0
# 27    7322108437674937630  2024-01-09T09:41:22             9.0
# 73    7321462210813775146  2024-01-07T15:52:59            61.0
# 74    7306946537563737390  2023-11-29T13:04:47            83.0
# 77    7321949971094277419  2024-01-08T23:25:55            34.0
# ...                   ...                  ...             ...
# 9022  7315405523514346798  2023-12-22T08:09:58             8.0
# 9066  7314109348161064234  2023-12-18T20:20:03             8.0
# 9070  7318170413140528430  1969-12-31T19:00:00             NaN
# 9159  7318948668009106693  2023-12-31T21:18:54            18.0
# 9172  7270227579288718635  2023-08-22T15:16:23            16.0
#
#      video_locationcreated                                    suggested_words  \
# 8                       US                                                NaN
# 27                      US                                                NaN
# 73                      US  Mario Balotelli, why always me, lance stephens...
# 74                      US  Joe Burrow, why did joe burrow wear joe burrea...
# 77                      US  michigan vs washington, michael penix jr, mich...
# ...                    ...                                                ...
# 9022                    US                                                NaN
# 9066                    US  pandemic tiktok dances, money real long, someb...
# 9070                   NaN                                                NaN
# 9159                    CA  andy cohen anderson cooper, andy cohen anderso...
# 9172                    US  hector bellerin speaking english, héctor belle...
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 8                 6.0               0.0                 0.0            789.0
# 27            26500.0             321.0               266.0         352500.0
# 73           354900.0             719.0               858.0        2200000.0
# 74           470600.0             855.0              1156.0        3500000.0
# 77           118900.0             466.0              1562.0        1400000.0
# ...               ...               ...                 ...              ...
# 9022          29500.0            3021.0               502.0         273000.0
# 9066        2000000.0            6673.0              4985.0        9700000.0
# 9070              NaN               NaN                 NaN              NaN
# 9159         448700.0           26900.0              1547.0        4000000.0
# 9172         229000.0           14300.0               882.0        1200000.0
#
#                                       video_description  ...  video_stickers  \
# 8     TIMO WERNER TO SPURS COMPLETE. How would you r...  ...             NaN
# 27    We need an official 40 time for Katt Williams ...  ...             NaN
# 73    Super Mario 🍄  #italy #balotelli #mariobalotel...  ...             NaN
# 74    Joe Shiesty 🤩🤩 #nfl #collegefootball #joeburro...  ...             NaN
# 77    #michaelpenixjr #washington #michigan #cfbplay...  ...             NaN
# ...                                                 ...  ...             ...
# 9022  #Meme #MemeCut #fyp #eagles #sports #football ...  ...             NaN
# 9066  good dances while we were locked up 🏡 #fyp #fo...  ...             NaN
# 9070                                                NaN  ...             NaN
# 9159  HAHAHAHA omg!!!!! Andy Cohen and Anderson Coop...  ...             NaN
# 9172  stop bc that intro video was actually so funny...  ...             NaN
#
#        author_username          author_name author_followercount  \
# 8     teaandtacklespod       TEA&TACKLESPOD                  NaN
# 27      bleacherreport       bleacherreport                  NaN
# 73    immortal.sports5      Immortal Sports                  NaN
# 74           banditott              Bandito                  NaN
# 77                espn                 ESPN                  NaN
# ...                ...                  ...                  ...
# 9022   drunkenmonkey82       Drunken Monkey                  NaN
# 9066             317ac             Ashton🕺🏾                  NaN
# 9070               NaN                  NaN                  NaN
# 9159  byewighellodrama  Bye Wig Hello Drama                  NaN
# 9172       multicinema              bri ⋆˚❀                  NaN
#
#       author_followingcount  author_heartcount  author_videocount  \
# 8                       NaN                NaN                NaN
# 27                      NaN                NaN                NaN
# 73                      NaN                NaN                NaN
# 74                      NaN                NaN                NaN
# 77                      NaN                NaN                NaN
# ...                     ...                ...                ...
# 9022                    NaN                NaN                NaN
# 9066                    NaN                NaN                NaN
# 9070                    NaN                NaN                NaN
# 9159                    NaN                NaN                NaN
# 9172                    NaN                NaN                NaN
#
#       author_diggcount  author_verified  \
# 8                  NaN            False
# 27                 NaN             True
# 73                 NaN            False
# 74                 NaN            False
# 77                 NaN             True
# ...                ...              ...
# 9022               NaN            False
# 9066               NaN            False
# 9070               NaN            False
# 9159               NaN            False
# 9172               NaN            False
#
#                                                hashtags
# 8     [soccer, football, podcast, transfers, timower...
# 27        [nba, nbabasketball, kattwilliams, kevinhart]
# 73    [italy, balotelli, mariobalotelli, supermario,...
# 74    [nfl, collegefootball, joeburrow, lsufootball,...
# 77    [michaelpenixjr, washington, michigan, cfbplay...
# ...                                                 ...
# 9022  [meme, memecut, fyp, eagles, sports, football,...
# 9066  [fyp, foryourpage, foryoupageofficiall, 4upage...
# 9070                                                 []
# 9159  [nye, newyearseve, happynewyear, andycohen, an...
# 9172  [héctorbellerín, hectorbellerinedit, hectorbel...
#
# [385 rows x 21 columns]

# %%
file_name = 'new_relevant_videos.csv' #change as needed
with open(file_name, 'w') as fout:
    newsDF.to_csv('new_relevant_videos.csv')
