# %%
import pandas as pd

hashtags = pd.read_csv('news_hashtags.csv')
creaters = pd.read_csv('news_creaters.csv')

# %%
hashtags
hashtags_list = hashtags['Hashtag name'].tolist()

# %%
#hashtags_list

# %%
creaters
creaters_list = creaters['Username'].tolist()

# %%
#creaters_list

# %%
dir_path = "/Users/sandyliu/tiktok-news-exposure/" # CHANGE ME!

# %%
file_to_process = dir_path + "2-collect-metadata-pyktok/final-metadata/RB-chunks/RB_chunk_3_metadata.csv"
data_to_filter = pd.read_csv(file_to_process) #change this line to parse different files
data_to_filter
# Out:
#                  video_id      video_timestamp  video_duration  \
# 0     7324136737440058667  2024-01-14T20:51:31             5.0
# 1     7327369017457659182  2024-01-23T13:55:03             5.0
# 2     7148800550337776938  2022-09-29T09:57:22            12.0
# 3     7296997007686634798  2023-11-02T18:35:21             0.0
# 4     7331572163759295790  2024-02-03T21:44:58            40.0
# ...                   ...                  ...             ...
# 9376  7324670883908439328  2024-01-16T07:24:11            14.0
# 9377  7323712979290180894  2024-01-13T17:27:24            62.0
# 9378  7324909586853432618  2024-01-16T22:50:26             0.0
# 9379  7325305071334329642  2024-01-18T00:25:31            18.0
# 9380  7044377755135544623  2021-12-21T23:23:28             8.0
#
#      video_locationcreated                                    suggested_words  \
# 0                       US                                                NaN
# 1                       US                                                NaN
# 2                       US                                                NaN
# 3                       US  Childbirth, giving birthing, A Baby Story, 39 ...
# 4                       US  he's a good man savanna, boyfriend and little ...
# ...                    ...                                                ...
# 9376                    CH  marta brazil football, marta highlights, what ...
# 9377                    US  university of idaho, idaho case 4 students, mo...
# 9378                    US                                                NaN
# 9379                    US                                                NaN
# 9380                    US                                                NaN
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0               993.0               9.0                12.0         163100.0
# 1              1601.0               7.0                12.0         233900.0
# 2            421600.0            4952.0              1115.0        2500000.0
# 3             49000.0             247.0               357.0         741900.0
# 4           5900000.0           16700.0             13800.0       25800000.0
# ...               ...               ...                 ...              ...
# 9376         197500.0             513.0              1125.0        1500000.0
# 9377         268500.0             802.0              1837.0        4100000.0
# 9378            908.0               4.0                 8.0          14700.0
# 9379          54500.0             358.0               196.0         243700.0
# 9380          78300.0             722.0               274.0        1500000.0
#
#                                       video_description  video_is_ad  \
# 0     double the disappointment and double the choki...        False
# 1     and the berry bombs💔 (sorry our apartment is a...        False
# 2     the difference between the two roommates…. #op...        False
# 3     I’ll make a video sharing the full story soon,...        False
# 4     literally sobbed making this🥹 I have the best ...        False
# ...                                                 ...          ...
# 9376  If 17-year-old Marta could see herself now. 🥹👑...        False
# 9377  The University of Idaho  demolished a house in...        False
# 9378                               Peak inside 💅🏽💅🏽💅🏽💅🏽        False
# 9379                I love it here ⭐️⭐️⭐️⭐️🤌🏽👩🏽‍❤️‍💋‍👨🏽        False
# 9380                                         Oh hi 🤪 ✈️        False
#
#       video_stickers           author_username author_name  \
# 0                NaN     thatonehotlatinachick    your mom
# 1                NaN     thatonehotlatinachick    your mom
# 2                NaN     thatonehotlatinachick    your mom
# 3                NaN     thatonehotlatinachick    your mom
# 4                NaN     thatonehotlatinachick    your mom
# ...              ...                       ...         ...
# 9376             NaN        fifawomensworldcup        FIFA
# 9377             NaN  chroniclesofoliviabackup      Olivia
# 9378             NaN                 kernsters   Kernsters
# 9379             NaN                 kernsters   Kernsters
# 9380             NaN                 kernsters   Kernsters
#
#       author_followercount  author_followingcount  author_heartcount  \
# 0                      NaN                    NaN                NaN
# 1                      NaN                    NaN                NaN
# 2                      NaN                    NaN                NaN
# 3                      NaN                    NaN                NaN
# 4                      NaN                    NaN                NaN
# ...                    ...                    ...                ...
# 9376                   NaN                    NaN                NaN
# 9377                   NaN                    NaN                NaN
# 9378                   NaN                    NaN                NaN
# 9379                   NaN                    NaN                NaN
# 9380                   NaN                    NaN                NaN
#
#       author_videocount  author_diggcount  author_verified
# 0                   NaN               NaN            False
# 1                   NaN               NaN            False
# 2                   NaN               NaN            False
# 3                   NaN               NaN            False
# 4                   NaN               NaN            False
# ...                 ...               ...              ...
# 9376                NaN               NaN             True
# 9377                NaN               NaN            False
# 9378                NaN               NaN            False
# 9379                NaN               NaN            False
# 9380                NaN               NaN            False
#
# [9381 rows x 20 columns]

# %%
data_to_filter = data_to_filter.loc[data_to_filter['video_locationcreated'] == 'US']

# %%
data_to_filter
# Out:
#                  video_id      video_timestamp  video_duration  \
# 0     7324136737440058667  2024-01-14T20:51:31             5.0
# 1     7327369017457659182  2024-01-23T13:55:03             5.0
# 2     7148800550337776938  2022-09-29T09:57:22            12.0
# 3     7296997007686634798  2023-11-02T18:35:21             0.0
# 4     7331572163759295790  2024-02-03T21:44:58            40.0
# ...                   ...                  ...             ...
# 9375  7320737583477345582  2024-01-05T17:01:22             7.0
# 9377  7323712979290180894  2024-01-13T17:27:24            62.0
# 9378  7324909586853432618  2024-01-16T22:50:26             0.0
# 9379  7325305071334329642  2024-01-18T00:25:31            18.0
# 9380  7044377755135544623  2021-12-21T23:23:28             8.0
#
#      video_locationcreated                                    suggested_words  \
# 0                       US                                                NaN
# 1                       US                                                NaN
# 2                       US                                                NaN
# 3                       US  Childbirth, giving birthing, A Baby Story, 39 ...
# 4                       US  he's a good man savanna, boyfriend and little ...
# ...                    ...                                                ...
# 9375                    US  Lulus Dress, lulus, Lulu's Wedding Dress, part...
# 9377                    US  university of idaho, idaho case 4 students, mo...
# 9378                    US                                                NaN
# 9379                    US                                                NaN
# 9380                    US                                                NaN
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0               993.0               9.0                12.0         163100.0
# 1              1601.0               7.0                12.0         233900.0
# 2            421600.0            4952.0              1115.0        2500000.0
# 3             49000.0             247.0               357.0         741900.0
# 4           5900000.0           16700.0             13800.0       25800000.0
# ...               ...               ...                 ...              ...
# 9375           9313.0             142.0                60.0        8600000.0
# 9377         268500.0             802.0              1837.0        4100000.0
# 9378            908.0               4.0                 8.0          14700.0
# 9379          54500.0             358.0               196.0         243700.0
# 9380          78300.0             722.0               274.0        1500000.0
#
#                                       video_description  video_is_ad  \
# 0     double the disappointment and double the choki...        False
# 1     and the berry bombs💔 (sorry our apartment is a...        False
# 2     the difference between the two roommates…. #op...        False
# 3     I’ll make a video sharing the full story soon,...        False
# 4     literally sobbed making this🥹 I have the best ...        False
# ...                                                 ...          ...
# 9375  the holidays may be over but party season is n...         True
# 9377  The University of Idaho  demolished a house in...        False
# 9378                               Peak inside 💅🏽💅🏽💅🏽💅🏽        False
# 9379                I love it here ⭐️⭐️⭐️⭐️🤌🏽👩🏽‍❤️‍💋‍👨🏽        False
# 9380                                         Oh hi 🤪 ✈️        False
#
#       video_stickers           author_username author_name  \
# 0                NaN     thatonehotlatinachick    your mom
# 1                NaN     thatonehotlatinachick    your mom
# 2                NaN     thatonehotlatinachick    your mom
# 3                NaN     thatonehotlatinachick    your mom
# 4                NaN     thatonehotlatinachick    your mom
# ...              ...                       ...         ...
# 9375             NaN                     lulus       Lulus
# 9377             NaN  chroniclesofoliviabackup      Olivia
# 9378             NaN                 kernsters   Kernsters
# 9379             NaN                 kernsters   Kernsters
# 9380             NaN                 kernsters   Kernsters
#
#       author_followercount  author_followingcount  author_heartcount  \
# 0                      NaN                    NaN                NaN
# 1                      NaN                    NaN                NaN
# 2                      NaN                    NaN                NaN
# 3                      NaN                    NaN                NaN
# 4                      NaN                    NaN                NaN
# ...                    ...                    ...                ...
# 9375                   NaN                    NaN                NaN
# 9377                   NaN                    NaN                NaN
# 9378                   NaN                    NaN                NaN
# 9379                   NaN                    NaN                NaN
# 9380                   NaN                    NaN                NaN
#
#       author_videocount  author_diggcount  author_verified
# 0                   NaN               NaN            False
# 1                   NaN               NaN            False
# 2                   NaN               NaN            False
# 3                   NaN               NaN            False
# 4                   NaN               NaN            False
# ...                 ...               ...              ...
# 9375                NaN               NaN             True
# 9377                NaN               NaN            False
# 9378                NaN               NaN            False
# 9379                NaN               NaN            False
# 9380                NaN               NaN            False
#
# [6811 rows x 20 columns]

# %%
data_to_filter = data_to_filter.loc[data_to_filter['video_is_ad'] == False]

# %%
data_to_filter
# Out:
#                  video_id      video_timestamp  video_duration  \
# 0     7324136737440058667  2024-01-14T20:51:31             5.0
# 1     7327369017457659182  2024-01-23T13:55:03             5.0
# 2     7148800550337776938  2022-09-29T09:57:22            12.0
# 3     7296997007686634798  2023-11-02T18:35:21             0.0
# 4     7331572163759295790  2024-02-03T21:44:58            40.0
# ...                   ...                  ...             ...
# 9373  7320311532062182702  2024-01-04T13:27:38            92.0
# 9377  7323712979290180894  2024-01-13T17:27:24            62.0
# 9378  7324909586853432618  2024-01-16T22:50:26             0.0
# 9379  7325305071334329642  2024-01-18T00:25:31            18.0
# 9380  7044377755135544623  2021-12-21T23:23:28             8.0
#
#      video_locationcreated                                    suggested_words  \
# 0                       US                                                NaN
# 1                       US                                                NaN
# 2                       US                                                NaN
# 3                       US  Childbirth, giving birthing, A Baby Story, 39 ...
# 4                       US  he's a good man savanna, boyfriend and little ...
# ...                    ...                                                ...
# 9373                    US  aussiedoodle, Dogs Of TikTok, Dog TikTok, dog ...
# 9377                    US  university of idaho, idaho case 4 students, mo...
# 9378                    US                                                NaN
# 9379                    US                                                NaN
# 9380                    US                                                NaN
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0               993.0               9.0                12.0         163100.0
# 1              1601.0               7.0                12.0         233900.0
# 2            421600.0            4952.0              1115.0        2500000.0
# 3             49000.0             247.0               357.0         741900.0
# 4           5900000.0           16700.0             13800.0       25800000.0
# ...               ...               ...                 ...              ...
# 9373         176900.0            4306.0              1809.0        1200000.0
# 9377         268500.0             802.0              1837.0        4100000.0
# 9378            908.0               4.0                 8.0          14700.0
# 9379          54500.0             358.0               196.0         243700.0
# 9380          78300.0             722.0               274.0        1500000.0
#
#                                       video_description  video_is_ad  \
# 0     double the disappointment and double the choki...        False
# 1     and the berry bombs💔 (sorry our apartment is a...        False
# 2     the difference between the two roommates…. #op...        False
# 3     I’ll make a video sharing the full story soon,...        False
# 4     literally sobbed making this🥹 I have the best ...        False
# ...                                                 ...          ...
# 9373  Artemis the Anarchist stiles again. He really ...        False
# 9377  The University of Idaho  demolished a house in...        False
# 9378                               Peak inside 💅🏽💅🏽💅🏽💅🏽        False
# 9379                I love it here ⭐️⭐️⭐️⭐️🤌🏽👩🏽‍❤️‍💋‍👨🏽        False
# 9380                                         Oh hi 🤪 ✈️        False
#
#       video_stickers           author_username     author_name  \
# 0                NaN     thatonehotlatinachick        your mom
# 1                NaN     thatonehotlatinachick        your mom
# 2                NaN     thatonehotlatinachick        your mom
# 3                NaN     thatonehotlatinachick        your mom
# 4                NaN     thatonehotlatinachick        your mom
# ...              ...                       ...             ...
# 9373             NaN              reecedegoede  Reece De Goede
# 9377             NaN  chroniclesofoliviabackup          Olivia
# 9378             NaN                 kernsters       Kernsters
# 9379             NaN                 kernsters       Kernsters
# 9380             NaN                 kernsters       Kernsters
#
#       author_followercount  author_followingcount  author_heartcount  \
# 0                      NaN                    NaN                NaN
# 1                      NaN                    NaN                NaN
# 2                      NaN                    NaN                NaN
# 3                      NaN                    NaN                NaN
# 4                      NaN                    NaN                NaN
# ...                    ...                    ...                ...
# 9373                   NaN                    NaN                NaN
# 9377                   NaN                    NaN                NaN
# 9378                   NaN                    NaN                NaN
# 9379                   NaN                    NaN                NaN
# 9380                   NaN                    NaN                NaN
#
#       author_videocount  author_diggcount  author_verified
# 0                   NaN               NaN            False
# 1                   NaN               NaN            False
# 2                   NaN               NaN            False
# 3                   NaN               NaN            False
# 4                   NaN               NaN            False
# ...                 ...               ...              ...
# 9373                NaN               NaN            False
# 9377                NaN               NaN            False
# 9378                NaN               NaN            False
# 9379                NaN               NaN            False
# 9380                NaN               NaN            False
#
# [6281 rows x 20 columns]

# %%
import re
def getHashtags(phrase):
    if isinstance(phrase, str):
        return re.findall(r'#(\S+)', phrase.lower())
    else:
        return []

data_to_filter['hashtags'] = data_to_filter['video_description'].apply(getHashtags)

def getSuggestedWords(phrase):
    if phrase is None:
        return []
    elif isinstance(phrase, str):
        return phrase.split(',')
    else:
        return []
    
data_to_filter['suggested_words'] = data_to_filter['suggested_words'].apply(getSuggestedWords)
# Out:
# /var/folders/s4/ppn80whx7vncf15l68hxt0tm0000gn/T/ipykernel_95562/1592711010.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_filter['hashtags'] = data_to_filter['video_description'].apply(getHashtags)
# /var/folders/s4/ppn80whx7vncf15l68hxt0tm0000gn/T/ipykernel_95562/1592711010.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_to_filter['suggested_words'] = data_to_filter['suggested_words'].apply(getSuggestedWords)

# %%
data_to_filter
# Out:
#                  video_id      video_timestamp  video_duration  \
# 0     7324136737440058667  2024-01-14T20:51:31             5.0
# 1     7327369017457659182  2024-01-23T13:55:03             5.0
# 2     7148800550337776938  2022-09-29T09:57:22            12.0
# 3     7296997007686634798  2023-11-02T18:35:21             0.0
# 4     7331572163759295790  2024-02-03T21:44:58            40.0
# ...                   ...                  ...             ...
# 9373  7320311532062182702  2024-01-04T13:27:38            92.0
# 9377  7323712979290180894  2024-01-13T17:27:24            62.0
# 9378  7324909586853432618  2024-01-16T22:50:26             0.0
# 9379  7325305071334329642  2024-01-18T00:25:31            18.0
# 9380  7044377755135544623  2021-12-21T23:23:28             8.0
#
#      video_locationcreated                                    suggested_words  \
# 0                       US                                                 []
# 1                       US                                                 []
# 2                       US                                                 []
# 3                       US  [Childbirth,  giving birthing,  A Baby Story, ...
# 4                       US  [he's a good man savanna,  boyfriend and littl...
# ...                    ...                                                ...
# 9373                    US  [aussiedoodle,  Dogs Of TikTok,  Dog TikTok,  ...
# 9377                    US  [university of idaho,  idaho case 4 students, ...
# 9378                    US                                                 []
# 9379                    US                                                 []
# 9380                    US                                                 []
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0               993.0               9.0                12.0         163100.0
# 1              1601.0               7.0                12.0         233900.0
# 2            421600.0            4952.0              1115.0        2500000.0
# 3             49000.0             247.0               357.0         741900.0
# 4           5900000.0           16700.0             13800.0       25800000.0
# ...               ...               ...                 ...              ...
# 9373         176900.0            4306.0              1809.0        1200000.0
# 9377         268500.0             802.0              1837.0        4100000.0
# 9378            908.0               4.0                 8.0          14700.0
# 9379          54500.0             358.0               196.0         243700.0
# 9380          78300.0             722.0               274.0        1500000.0
#
#                                       video_description  ...  video_stickers  \
# 0     double the disappointment and double the choki...  ...             NaN
# 1     and the berry bombs💔 (sorry our apartment is a...  ...             NaN
# 2     the difference between the two roommates…. #op...  ...             NaN
# 3     I’ll make a video sharing the full story soon,...  ...             NaN
# 4     literally sobbed making this🥹 I have the best ...  ...             NaN
# ...                                                 ...  ...             ...
# 9373  Artemis the Anarchist stiles again. He really ...  ...             NaN
# 9377  The University of Idaho  demolished a house in...  ...             NaN
# 9378                               Peak inside 💅🏽💅🏽💅🏽💅🏽  ...             NaN
# 9379                I love it here ⭐️⭐️⭐️⭐️🤌🏽👩🏽‍❤️‍💋‍👨🏽  ...             NaN
# 9380                                         Oh hi 🤪 ✈️  ...             NaN
#
#                author_username     author_name author_followercount  \
# 0        thatonehotlatinachick        your mom                  NaN
# 1        thatonehotlatinachick        your mom                  NaN
# 2        thatonehotlatinachick        your mom                  NaN
# 3        thatonehotlatinachick        your mom                  NaN
# 4        thatonehotlatinachick        your mom                  NaN
# ...                        ...             ...                  ...
# 9373              reecedegoede  Reece De Goede                  NaN
# 9377  chroniclesofoliviabackup          Olivia                  NaN
# 9378                 kernsters       Kernsters                  NaN
# 9379                 kernsters       Kernsters                  NaN
# 9380                 kernsters       Kernsters                  NaN
#
#       author_followingcount  author_heartcount  author_videocount  \
# 0                       NaN                NaN                NaN
# 1                       NaN                NaN                NaN
# 2                       NaN                NaN                NaN
# 3                       NaN                NaN                NaN
# 4                       NaN                NaN                NaN
# ...                     ...                ...                ...
# 9373                    NaN                NaN                NaN
# 9377                    NaN                NaN                NaN
# 9378                    NaN                NaN                NaN
# 9379                    NaN                NaN                NaN
# 9380                    NaN                NaN                NaN
#
#       author_diggcount  author_verified  \
# 0                  NaN            False
# 1                  NaN            False
# 2                  NaN            False
# 3                  NaN            False
# 4                  NaN            False
# ...                ...              ...
# 9373               NaN            False
# 9377               NaN            False
# 9378               NaN            False
# 9379               NaN            False
# 9380               NaN            False
#
#                                                hashtags
# 0     [cowboys, utk, dallascowboys, govols, pain, do...
# 1                                [utk, bluemfs, uptown]
# 2                          [opposites, biglittlereveal]
# 3     [preeclampsia, birthstory, preeclampsiaawareness]
# 4     [fyp, littlesister, fiance, daddydaughterdance...
# ...                                                 ...
# 9373         [aussiethings, aissiedoodle, dogsoftiktok]
# 9377  [idahocollege, idahocollegestudents, idaho4, k...
# 9378                                                 []
# 9379                                                 []
# 9380                                                 []
#
# [6281 rows x 21 columns]

# %%
def filter_conditions(row):
    has_hashtag = isinstance(row['hashtags'], list) and any(hashtag in row['hashtags'] for hashtag in hashtags_list)
    is_creator = row['author_username'] in creaters_list
    has_suggested_word = isinstance(row['suggested_words'], list) and any(word in row['suggested_words'] for word in hashtags_list)
    
    return has_hashtag or is_creator or has_suggested_word

data_to_filter_result = data_to_filter[data_to_filter.apply(filter_conditions, axis=1)]

## if hashtags is indeed a list, check if there is overlap between the video hashtag and the hashtag list or if the video 
## content creator is a news account. If any of the two is satisfied, pass to new dataset newsDF.

# %%
data_to_filter_result
## This result is actually a bit too weird
# Out:
#                  video_id      video_timestamp  video_duration  \
# 73    7331583352866180394  2024-02-03T22:28:22            11.0
# 109   7331559337430633770  2024-02-03T20:55:01             0.0
# 128   7304006914596162846  2023-11-21T14:57:24            25.0
# 201   7331547023889632558  2024-02-03T20:07:21            26.0
# 296   7331444709346299182  2024-02-03T13:30:22             0.0
# ...                   ...                  ...             ...
# 9210  7324105883141655851  2024-01-14T18:51:49            85.0
# 9282  7226743065522769195  2023-04-27T10:54:09            33.0
# 9364  7325625594228509998  2024-01-18T21:09:11            45.0
# 9370  7325989701897260334  2024-01-19T20:42:01             0.0
# 9377  7323712979290180894  2024-01-13T17:27:24            62.0
#
#      video_locationcreated                                    suggested_words  \
# 73                      US  [klay thompson,  Steph Curry,  curry 60 point ...
# 109                     US                                                 []
# 128                     US                                                 []
# 201                     US                                                 []
# 296                     US  [juju watkins,  Basket Ball,  Sports,  Basketb...
# ...                    ...                                                ...
# 9210                    US                                                 []
# 9282                    US  [lea michele,  Salma Hayek,  Kim Kardashian,  ...
# 9364                    US  [travis kelce taylor swift,  Travis Kelce And ...
# 9370                    US                                                 []
# 9377                    US  [university of idaho,  idaho case 4 students, ...
#
#       video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 73           356200.0            2620.0              5265.0        3700000.0
# 109           36500.0              99.0               147.0         658400.0
# 128              16.0               0.0                 0.0           1657.0
# 201           24600.0             136.0               208.0         345400.0
# 296           33600.0             423.0               249.0         683800.0
# ...               ...               ...                 ...              ...
# 9210             60.0               0.0                 0.0            866.0
# 9282        2900000.0            5294.0              4292.0       36200000.0
# 9364         444400.0           20500.0             13100.0        6900000.0
# 9370          14700.0             179.0               440.0         348000.0
# 9377         268500.0             802.0              1837.0        4100000.0
#
#                                       video_description  ...  video_stickers  \
# 73    Hawks spoiled Curry’s 60 piece 👀 #nba #basketb...  ...             NaN
# 109   Grant Williams repping a Satou Sabally shirt m...  ...             NaN
# 128   Product: BLOOM | Fluffy Bowtie Headband Set 🎀 ...  ...             NaN
# 201   ♥️😂(via @NBC Sports Bay Area & CA) #stephcurry...  ...             NaN
# 296   #JuJuWatkins had one of the most memorable bou...  ...             NaN
# ...                                                 ...  ...             ...
# 9210  he sure is lovin all this snow! #fyp #fypシ #fo...  ...             NaN
# 9282  We asked celebs the most expensive thing they ...  ...             NaN
# 9364  Replying to @toakes I’ll just sit this right h...  ...             NaN
# 9370  Breaking: Former #Alabama safety and SEC Fresh...  ...             NaN
# 9377  The University of Idaho  demolished a house in...  ...             NaN
#
#                author_username               author_name author_followercount  \
# 73              bleacherreport            bleacherreport                  NaN
# 109             bleacherreport            bleacherreport                  NaN
# 128         skincarewith.bloom  BLOOM - Your Esthetician                  NaN
# 201                       espn                      ESPN                  NaN
# 296                       espn                      ESPN                  NaN
# ...                        ...                       ...                  ...
# 9210                   gtfo123              madalyn.cash                  NaN
# 9282               buzzfeednow              BuzzFeed Now                  NaN
# 9364          the_real_ellebee                    ✨Elle✨                  NaN
# 9370                      espn                      ESPN                  NaN
# 9377  chroniclesofoliviabackup                    Olivia                  NaN
#
#       author_followingcount  author_heartcount  author_videocount  \
# 73                      NaN                NaN                NaN
# 109                     NaN                NaN                NaN
# 128                     NaN                NaN                NaN
# 201                     NaN                NaN                NaN
# 296                     NaN                NaN                NaN
# ...                     ...                ...                ...
# 9210                    NaN                NaN                NaN
# 9282                    NaN                NaN                NaN
# 9364                    NaN                NaN                NaN
# 9370                    NaN                NaN                NaN
# 9377                    NaN                NaN                NaN
#
#       author_diggcount  author_verified  \
# 73                 NaN             True
# 109                NaN             True
# 128                NaN            False
# 201                NaN             True
# 296                NaN             True
# ...                ...              ...
# 9210               NaN            False
# 9282               NaN             True
# 9364               NaN            False
# 9370               NaN             True
# 9377               NaN            False
#
#                                                hashtags
# 73              [nba, basketball, stephcurry, warriors]
# 109    [nba, basketball, dallasmavericks, satousabally]
# 128   [skincare, blackgirltiktok, fyp, facialtreatme...
# 201                          [stephcurry, lindsaylohan]
# 296   [jujuwatkins, basketball, collegebasketball, w...
# ...                                                 ...
# 9210  [fyp, fypシ, foryoupage, dogsoftiktok, pitbulls...
# 9282  [time100gala, kimkardashian, leamichele, salma...
# 9364  [nfl, traviskelce, football, taylorswift, love...
# 9370  [alabama, calebdowns, ohiostate,, petethamel.,...
# 9377  [idahocollege, idahocollegestudents, idaho4, k...
#
# [415 rows x 21 columns]

# %%
file_name = 'new_relevant_videos.csv' #change as needed
with open(file_name, 'w') as fout:
    newsDF.to_csv('new_relevant_videos_chunk_3.csv')
