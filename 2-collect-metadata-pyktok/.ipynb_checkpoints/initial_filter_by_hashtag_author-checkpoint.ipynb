# %%
import pandas as pd

hashtags = pd.read_csv('news_hashtags.csv')
creaters = pd.read_csv('news_creaters.csv')

# %%
hashtags
hashtags_list = hashtags['Hashtag name'].tolist()

# %%
creaters
creaters_list = creaters['Username'].tolist()

# %%
data_to_filter = pd.read_csv('TEST-results.csv') #change this line to parse different files
data_to_filter
# Out:
#                 video_id      video_timestamp  video_duration  \
# 0    7280779115760733482  2023-09-20T01:41:38             321
# 1    7338804441702862111  2024-02-23T09:29:40               8
# 2    7281173547069001006  2023-09-21T03:12:16              12
# 3    7280261400805575966  2023-09-18T16:12:43               0
# 4    7333422897228156202  2024-02-08T21:26:32              14
# ..                   ...                  ...             ...
# 193  7342267799882009888  2024-03-03T17:29:09              12
# 194  7341537402684525866  2024-03-01T18:15:05              10
# 195  7337846537759771950  2024-02-20T19:32:26              17
# 196  7339339777281510698  2024-02-24T20:07:20              61
# 197  7338499139531017474  2024-02-22T13:44:41              16
#
#     video_locationcreated                                    suggested_words  \
# 0                      US                                                NaN
# 1                      US  Cap Cut Template, capcut edit templates, templ...
# 2                      GB                                                NaN
# 3                      GB                                                NaN
# 4                      AU  Scott Disick, penelope kardashians, Pandkourt,...
# ..                    ...                                                ...
# 193                    GB  alex consani, alex consani runway, alex consan...
# 194                    US  back on 74 dance, back on 74 by jungle, back t...
# 195                    US  dune 2 edit, Dune, Dune Movie, timothée chalam...
# 196                    US  mark sloan, mark and lexie, mcdreamy, mark slo...
# 197               FAKE-AD  Fitness Training, Fitness TikTok, fitness work...
#
#      video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0               2206               150                  59            19500
# 1              22300               102                 356           883900
# 2                 23                 0                   0              483
# 3                 41                 0                   6              544
# 4             351400               676                   0          2200000
# ..               ...               ...                 ...              ...
# 193           774400              1050                 777          4800000
# 194           165900               171                 234           619100
# 195            88600               657                 228           434500
# 196          1100000              6539                2782          4200000
# 197              539                 4                   4           157400
#
#                                      video_description  video_is_ad  \
# 0    #stitch with @hasty some of you probably prono...        False
# 1    #CapCut @⚜️inxky⚜️ #fyp #viral #template #capc...        False
# 2                                                  NaN        False
# 3                                                  NaN        False
# 4                                                  NaN        False
# ..                                                 ...          ...
# 193  Replying to @Caitlin Jones310 Backstage with @...        False
# 194                                                NaN        False
# 195  for this lil' #askthedunecast i want to know t...        False
# 196  Mcsteamy😍😍😍 #marksloan #marksloanedit #greysan...        False
# 197  Teaching fitness can take you places you only ...         True
#
#      video_stickers           author_username             author_name  \
# 0               NaN               failedviner       Tan | failedviner
# 1               NaN  capcuttemplatesthatifind  findingtemplatesforyou
# 2               NaN                  .junonia                 natalie
# 3               NaN                  .junonia                 natalie
# 4               NaN                 pandkourt       Kourtney-Penelope
# ..              ...                       ...                     ...
# 193             NaN                     dazed                   dazed
# 194             NaN                   prejoye                precious
# 195             NaN                  ashlliex          ellie williams
# 196             NaN                 greysan19                       🗿
# 197             NaN                 Les Mills               Les Mills
#
#      author_followercount  author_followingcount  author_heartcount  \
# 0                     NaN                    NaN                NaN
# 1                     NaN                    NaN                NaN
# 2                     NaN                    NaN                NaN
# 3                     NaN                    NaN                NaN
# 4                     NaN                    NaN                NaN
# ..                    ...                    ...                ...
# 193                   NaN                    NaN                NaN
# 194                   NaN                    NaN                NaN
# 195                   NaN                    NaN                NaN
# 196                   NaN                    NaN                NaN
# 197                   NaN                    NaN                NaN
#
#      author_videocount  author_diggcount  author_verified
# 0                  NaN               NaN            False
# 1                  NaN               NaN            False
# 2                  NaN               NaN            False
# 3                  NaN               NaN            False
# 4                  NaN               NaN             True
# ..                 ...               ...              ...
# 193                NaN               NaN             True
# 194                NaN               NaN            False
# 195                NaN               NaN            False
# 196                NaN               NaN            False
# 197                NaN               NaN            False
#
# [198 rows x 20 columns]

# %%
import re
def getHashtags(phrase):
    if isinstance(phrase, str):
        return re.findall(r'#(\S+)', phrase.lower())
    else:
        return []

data_to_filter['hashtags'] = data_to_filter['video_description'].apply(getHashtags)
data_to_filter
# Out:
#                 video_id      video_timestamp  video_duration  \
# 0    7280779115760733482  2023-09-20T01:41:38             321
# 1    7338804441702862111  2024-02-23T09:29:40               8
# 2    7281173547069001006  2023-09-21T03:12:16              12
# 3    7280261400805575966  2023-09-18T16:12:43               0
# 4    7333422897228156202  2024-02-08T21:26:32              14
# ..                   ...                  ...             ...
# 193  7342267799882009888  2024-03-03T17:29:09              12
# 194  7341537402684525866  2024-03-01T18:15:05              10
# 195  7337846537759771950  2024-02-20T19:32:26              17
# 196  7339339777281510698  2024-02-24T20:07:20              61
# 197  7338499139531017474  2024-02-22T13:44:41              16
#
#     video_locationcreated                                    suggested_words  \
# 0                      US                                                NaN
# 1                      US  Cap Cut Template, capcut edit templates, templ...
# 2                      GB                                                NaN
# 3                      GB                                                NaN
# 4                      AU  Scott Disick, penelope kardashians, Pandkourt,...
# ..                    ...                                                ...
# 193                    GB  alex consani, alex consani runway, alex consan...
# 194                    US  back on 74 dance, back on 74 by jungle, back t...
# 195                    US  dune 2 edit, Dune, Dune Movie, timothée chalam...
# 196                    US  mark sloan, mark and lexie, mcdreamy, mark slo...
# 197               FAKE-AD  Fitness Training, Fitness TikTok, fitness work...
#
#      video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 0               2206               150                  59            19500
# 1              22300               102                 356           883900
# 2                 23                 0                   0              483
# 3                 41                 0                   6              544
# 4             351400               676                   0          2200000
# ..               ...               ...                 ...              ...
# 193           774400              1050                 777          4800000
# 194           165900               171                 234           619100
# 195            88600               657                 228           434500
# 196          1100000              6539                2782          4200000
# 197              539                 4                   4           157400
#
#                                      video_description  ...  video_stickers  \
# 0    #stitch with @hasty some of you probably prono...  ...             NaN
# 1    #CapCut @⚜️inxky⚜️ #fyp #viral #template #capc...  ...             NaN
# 2                                                  NaN  ...             NaN
# 3                                                  NaN  ...             NaN
# 4                                                  NaN  ...             NaN
# ..                                                 ...  ...             ...
# 193  Replying to @Caitlin Jones310 Backstage with @...  ...             NaN
# 194                                                NaN  ...             NaN
# 195  for this lil' #askthedunecast i want to know t...  ...             NaN
# 196  Mcsteamy😍😍😍 #marksloan #marksloanedit #greysan...  ...             NaN
# 197  Teaching fitness can take you places you only ...  ...             NaN
#
#               author_username             author_name author_followercount  \
# 0                 failedviner       Tan | failedviner                  NaN
# 1    capcuttemplatesthatifind  findingtemplatesforyou                  NaN
# 2                    .junonia                 natalie                  NaN
# 3                    .junonia                 natalie                  NaN
# 4                   pandkourt       Kourtney-Penelope                  NaN
# ..                        ...                     ...                  ...
# 193                     dazed                   dazed                  NaN
# 194                   prejoye                precious                  NaN
# 195                  ashlliex          ellie williams                  NaN
# 196                 greysan19                       🗿                  NaN
# 197                 Les Mills               Les Mills                  NaN
#
#      author_followingcount  author_heartcount  author_videocount  \
# 0                      NaN                NaN                NaN
# 1                      NaN                NaN                NaN
# 2                      NaN                NaN                NaN
# 3                      NaN                NaN                NaN
# 4                      NaN                NaN                NaN
# ..                     ...                ...                ...
# 193                    NaN                NaN                NaN
# 194                    NaN                NaN                NaN
# 195                    NaN                NaN                NaN
# 196                    NaN                NaN                NaN
# 197                    NaN                NaN                NaN
#
#      author_diggcount  author_verified  \
# 0                 NaN            False
# 1                 NaN            False
# 2                 NaN            False
# 3                 NaN            False
# 4                 NaN             True
# ..                ...              ...
# 193               NaN             True
# 194               NaN            False
# 195               NaN            False
# 196               NaN            False
# 197               NaN            False
#
#                                               hashtags
# 0    [stitch, pokemon, videogames, smogon, vgc, ani...
# 1         [capcut, fyp, viral, template, capcut, edit]
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 193  [dazedfashiontv, tiktokfashion, alexconsani, m...
# 194                                                 []
# 195  [askthedunecast, ashlliex, dune, dunemovie, du...
# 196  [marksloan, marksloanedit, greysanatomy, greys...
# 197                                                 []
#
# [198 rows x 21 columns]

# %%
newsDF = data_to_filter[data_to_filter.apply(lambda row: 
                      (isinstance(row['hashtags'], list) and 
                       any(hashtag in row['hashtags'] for hashtag in hashtags_list)) 
                      or row['author_username'] in creaters_list, axis=1)]

## if hashtags is indeed a list, check if there is overlap between the video hashtag and the hashtag list or if the video 
## content creator is a news account. If any of the two is satisfied, pass to new dataset newsDF.

# %%
newsDF
## This result is actually a bit too weird
# Out:
#                 video_id      video_timestamp  video_duration  \
# 89   7342623988755057966  2024-03-04T16:31:46               0
# 135  7338257395610602782  2024-02-21T22:07:09              20
# 143  7339575392237407521  2024-02-25T11:21:11              15
# 150  7342621870191201582  2024-03-04T16:23:33               0
# 156  7340477137285287214  2024-02-27T21:40:27              66
#
#     video_locationcreated                                    suggested_words  \
# 89                     US  Russell Wilson, broncos, Denver Broncos, NFL F...
# 135                    US  Messi, inter miami, lionel messi, Leo Messi In...
# 143                    IT  Travis Kelce SNL, travis kelce edits, travis k...
# 150                    US  russell wilson, russell wilson release, bronco...
# 156                    US  calvin ridley, nightcrawler edit, Football Pla...
#
#      video_diggcount  video_sharecount  video_commentcount  video_playcount  \
# 89              9286               584                 607           499700
# 135           336500              8976                4005          5100000
# 143           342000              5087                1550          2300000
# 150            75900              1345                1995           952800
# 156            76400                85                 247           474900
#
#                                      video_description  ...  video_stickers  \
# 89   Breaking: The Denver #Broncos announced that t...  ...             NaN
# 135  THIS MESSI MOVE. 🤯🤯 #lionelmessi #messi #inter...  ...             NaN
# 143  TRAVIS KELCE?🗣🗣 #nfl #traviskelce #travis #kel...  ...             NaN
# 150  🚨 Breaking: Russell Wilson has been released b...  ...             NaN
# 156  this kinda sucks but i forgot to post it #nfl ...  ...             NaN
#
#        author_username          author_name author_followercount  \
# 89                espn                 ESPN                  NaN
# 135  houseofhighlights  House of Highlights                  NaN
# 143        travkelce13             tkelce13                  NaN
# 150     bleacherreport       bleacherreport                  NaN
# 156         jaguarpost               𝕵𝖆𝖌𝖚𝖆𝖗                  NaN
#
#      author_followingcount  author_heartcount  author_videocount  \
# 89                     NaN                NaN                NaN
# 135                    NaN                NaN                NaN
# 143                    NaN                NaN                NaN
# 150                    NaN                NaN                NaN
# 156                    NaN                NaN                NaN
#
#      author_diggcount  author_verified  \
# 89                NaN             True
# 135               NaN             True
# 143               NaN            False
# 150               NaN             True
# 156               NaN            False
#
#                                               hashtags
# 89             [broncos, russellwilson, nfl, football]
# 135  [lionelmessi, messi, intermiami, mls, football...
# 143  [nfl, traviskelce, travis, kelce, fyp, edit, v...
# 150                       [nfl, nflfootball, football]
# 156  [nfl, sports, calvinridley, jaguars, jacksovil...
#
# [5 rows x 21 columns]
